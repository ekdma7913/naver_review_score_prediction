# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import os
import time

import pandas as pd
import openpyxl

# %%
xlsx = pd.read_excel('KOBIS_역대_박스오피스_내역.xlsx',engine="openpyxl")

# %%
movie = []

# 박스오피스 영화 순위 100
for x in xlsx["영화명"][0:100]:
    movie.append(x)

print(movie)
# Out:
# ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '어벤져스: 엔드게임', '겨울왕국 2', '아바타', '베테랑', '괴물', '도둑들', '7번방의 선물', '암살', '알라딘', '광해, 왕이 된 남자', '왕의 남자', '신과함께-인과 연', '택시운전사', '태극기 휘날리며', '부산행', '해운대', '변호인', '어벤져스: 인피니티 워', '실미도', '어벤져스: 에이지 오브 울트론', '기생충', '겨울왕국', '인터스텔라', '보헤미안 랩소디', '검사외전', '엑시트', '설국열차', '관상', '아이언맨 3', '캡틴 아메리카: 시빌 워', '해적: 바다로 간 산적', '수상한 그녀', '국가대표', '디워', '백두산', '과속스캔들', '스파이더맨: 파 프롬 홈', '웰컴 투 동막골', '공조', '트랜스포머 3', '히말라야', '미션임파서블:고스트프로토콜', '트랜스포머: 패자의 역습', '밀정', '최종병기 활', '트랜스포머', '써니', '화려한 휴가', '스파이더맨: 홈 커밍', 1987, '베를린', '마스터', '터널', '어벤져스', '내부자들', '인천상륙작전', '럭키', '은밀하게 위대하게', '곡성', '범죄도시', '타짜', '좋은 놈, 나쁜 놈, 이상한 놈', '늑대소년', '미녀는 괴로워', '군함도', '미션 임파서블: 폴아웃', '다크 나이트 라이즈', '아저씨', '사도', '전우치', '킹스맨 : 시크릿 에이전트', '미션 임파서블: 로그네이션', '투사부일체', '연평해전', '반지의 제왕 : 왕의 귀환', '인셉션', '레미제라블', '쉬리', '캡틴 마블', '미션 임파서블 3', '쥬라기 월드: 폴른 킹덤', '청년경찰', '가문의 위기(가문의 영광2)', '숨바꼭질', '덕혜옹주', '더 테러 라이브', '스파이더맨: 노 웨이 홈', '쥬라기 월드', '감시자들', '의형제', 2012, '앤트맨과 와스프', '닥터 스트레인지', '검은 사제들', '안시성', '블랙 팬서']

# %%
## 영화 코드 추출
## 영화 검색 -> 영화 목록 리스트 -> 리스트 중 하나를 검색하면 제일 먼저 앞에 나오는 걸 영화로 지칭하고 그 안의 코드를 추출
data2 = []

driver = webdriver.Chrome()

# 영화 목록

movie_list = open("영화코드.txt","w")

for x in movie:
    driver.get("https://movie.naver.com/movie/search/result.naver?section=movie&query="+str(x))
    time.sleep(1)
    q = driver.find_element(By.XPATH, "/html/body/div/div[4]/div/div/div/div/div[1]/ul[2]/li[1]/dl/dt")
    w = q.find_element(By.TAG_NAME,"a")
    e = w.get_attribute("href")
    data2.append(e[53:])
    movie_list.write(str(e[53:])+"\n") # 문제 있는 텍스트임
    #print(e[53:])
    
movie_list.close()

# %%
## 검색해서 다른 영화를 지목하는 경우가 있음 -> 일일이 수정해놓자

for x,i in enumerate(data2):
    print(x,i)
# Out:
# 0 133253
# 1 167651
# 2 85579
# 3 102875
# 4 136900
# 5 136873
# 6 84024
# 7 115977
# 8 210812
# 9 210927
# 10 94775
# 11 121048
# 12 163788
# 13 83893
# 14 39894
# 15 167697
# 16 146469
# 17 36666
# 18 130966
# 19 45321
# 20 101901
# 21 136315
# 22 34501
# 23 98438
# 24 161967
# 25 136873
# 26 149545
# 27 156464
# 28 130903
# 29 203021
# 30 62328
# 31 93728
# 32 70254
# 33 122527
# 34 102817
# 35 107924
# 36 141824
# 37 39569
# 38 187940
# 39 51143
# 40 173123
# 41 39405
# 42 142384
# 43 70241
# 44 100647
# 45 53372
# 46 68052
# 47 137952
# 48 83084
# 49 123630
# 50 212745
# 51 58018
# 52 135874
# 53 158191
# 54 158100
# 55 145162
# 56 199913
# 57 136900
# 58 121788
# 59 142822
# 60 196284
# 61 92575
# 62 121051
# 63 192608
# 64 96951
# 65 65674
# 66 135725
# 67 39157
# 68 146506
# 69 154222
# 70 72054
# 71 122851
# 72 121922
# 73 48227
# 74 114249
# 75 95541
# 76 41450
# 77 102272
# 78 31796
# 79 191735
# 80 191469
# 81 19500
# 82 132623
# 83 43153
# 84 154285
# 85 153652
# 86 41438
# 87 195326
# 88 94767
# 89 211939
# 90 208077
# 91 191646
# 92 98146
# 93 52548
# 94 110457
# 95 144330
# 96 182016
# 97 197843
# 98 163533
# 99 137326

# %%
## 검색후 코드 잘못 부른 영화 일일이 다른 항목들 다 수정함 ㅠ

#명량 0 : 93756
#아바타 6 : 62266
#괴물 8 : 39841
#아미?
#겨울왕국 25 : 100931
#인터스텔라 26 : 45290
#엑시트 29 : 174903
#국가대표 37 : 47385
#트랜스포머49 : 61521
#써니 50 : 76016
#베를린 54: 89218
#터널 56: 141104
#어벤저스 57: 72363
#럭키 60: 140695
#범죄도시 63: 161242
#타자 64: 57723
#느대소년 66: 88253
#아저씨 71: 71509
#인셉션 79: 52515
#레미제라블 80: 89755
#숨바꼭질 87: 102824
#더테러라이브 89: 99794
#쥬라기월드 91: 67786
#2012 94: 49727
#닥터스트렌인지 96: 125459
#검은사제들 97: 120157
#...
#data2[9] = "78726"

# %%
movie_real = open("영화목록_리얼.txt","w")
for x in data2:
    movie_real.write(x+"\n")

# %%
len(data2)
# Out:
# 100

# %%
## 노-력의 흔적

#c = driver.find_elements(By.XPATH,"/html/body/div/div[4]/div/div/div/div/div[1]/ul[2]/li[1]/dl/dt")
#c = driver.find_element(By.CLASS_NAME,"search_list_1")

#href 태그 내 이름 추출

'''q = driver.find_element(By.XPATH, "/html/body/div/div[4]/div/div/div/div/div[1]/ul[2]/li[1]/dl/dt")
w = q.find_element(By.TAG_NAME,"a")
e = w.get_attribute("href")
#print(e)
print(e[53:]) # 53번째 부터 숫자가 나옴'''
# Out:
# https://movie.naver.com/movie/bi/mi/basic.naver?code=167651
# 167651
# 'for x in q:\n    print(x.text)'

# %%
## 영화 관련 정보 추출
driver = webdriver.Chrome()
data = []
# 내가 읽고 싶은 페이지 수
page = 20

for z in data2:
    for a in range(1,page+1): # 페이지1장 당 20개의 리뷰
        #다음 장 넘기기
        driver.get("https://movie.naver.com/movie/point/af/list.naver?st=mcode&sword="+str(z)+"&target=after&page="+str(a))
        time.sleep(2)
        # 영화 이름 20개 이름, 별점, 리뷰내용 추출
        b = driver.find_elements(By.CLASS_NAME,"title")
        for x in range(10):
            # 영화 이름
            name = b[x].text.split("\n")[0]

            # 영화 평점 별점
            num = b[x].text.split("\n")[2]

            # 영화 평점 내용
            review = b[x].text.split("\n")[3][:-3]

            data.append(np.asarray((name,num,review)))
        
data_df = pd.DataFrame(data,columns=['name','num','review'])

# %%
data
# Out:
# [array(['명량', '10', '역대 대명작이라 자부합니다^^'], dtype='<U16'),
#  array(['명량', '10',
#         '진짜 이건 우리나라 영화계에 한 획을 그을 정도에 명작입니다 우리가 역사를 배워야 하는 이유도, 잊지 말아야 하는 이유도 이 영화에 담겨있습니다...'],
#        dtype='<U83'),
#  array(['명량', '3', '국뽕 범벅, 거품, 스크린독점 관객동원'], dtype='<U21'),
#  array(['명량', '10',
#         '초등 고학년 아들과 진도에 다녀온후 같이 봣는데 정말 감사하고 감동이며 죄송스러운 마음이 겹치네요'],
#        dtype='<U54'),
#  array(['명량', '10',
#         '깊게 숨을 들이쉬고 후하고 내뱉은 뒤, 이 영화를 보아라. 다보고 나서 이틀 뒤에 30분동안 조깅하고 나서 청국장을 먹은뒤에 이 영화를 다시보아라. 그리고, 일주일 뒤 모두가 잠이든 새벽에 불을 다 끄고 이 영화를 다시보아라. 그러면, 알게 될것이다. 이영화는 한치의 흠도 없이 완벽하게 이순신장군과 명량해전을 연출했다는 것을. 나는 이 영화를 만든 감독을 존경하게 되었다.'],
#        dtype='<U209'),
#  array(['명량', '10', '지낮ㅇㅇ당터더야어주준'], dtype='<U11'),
#  array(['명량', '5',
#         '훌룡한 배우진과 역사적 재료를 살리지못한 루즈한 연출과 스토리 전개로 인해 후반으로 갈수록 지루해진다.'],
#        dtype='<U57'),
#  array(['명량', '1', '수준 낮은 영화. 이걸 명작이라고 떠들어 대는 이들의 정신상태가 의심스럽다'],
#        dtype='<U41'),
#  array(['명량', '10', ''], dtype='<U2'),
#  array(['명량', '10', ''], dtype='<U2'),
#  array(['명량', '10', '이제야 대작을 봅니다 시간가는 줄 모르고 봤네요~^^'], dtype='<U29'),
#  array(['명량', '10', '이순신 장군님 너무 감사합니다.지금 대한민국이 건제하는거에 너무 감사합니다.0'],
#        dtype='<U43'),
#  array(['명량', '10', '나라를 지키기 위해 끝까지 싸우신 이순신 장군님 감사하고 사랑하고 존경합니다.'],
#        dtype='<U43'),
#  array(['명량', '10',
#         '연출 긴장감 연기력 완벽하다역사를 알면 고증이 얼마나 잘되었는지 알듯하다이순신 장군님의 내면 고민도 잘 표현했고….넷플로 8번 봤는데 보면 볼수록 잘 만든 영화!!'],
#        dtype='<U91'),
#  array(['명량', '10', '잊지말아야 할 그이름 이순신'], dtype='<U15'),
#  array(['명량', '10', '너무 재밌게 봤습니다!! 배경음악도 너무 좋네요'], dtype='<U26'),
#  array(['명량', '10',
#         '연기가 너무 좋고 배경이라던가 가족영화라 해도 너무 좋은내용인것 같아서 재미있고약간의 감동이 있다'],
#        dtype='<U54'),
#  array(['명량', '2', '국뽕 충만 개돼지들 눈물 바다.'], dtype='<U17'),
#  array(['명량', '10',
#         '국뽕을 빼고 봐야 이순신장군이 제대로 보임. 국뽕을 빼면 이순신 장군은 우리가 생각하는것 보다 천배는 더 위대해보인다는 것. 세계에서 봐도 이런분이 없음.'],
#        dtype='<U86'),
#  array(['명량', '10', '예전 극장에서 정말 잘봤음'], dtype='<U14'),
#  array(['명량', '1', '와 ㅅ바 이게 광해를 넘어섰다고??? 최민식빨 없었으면 진짜 어땠을까'], dtype='<U38'),
#  array(['명량', '4', '국뽕 감성팔이 상업용 영화'], dtype='<U14'),
#  array(['명량', '10',
#         '영화에서 말도안된다면서 욕하는 사람들ㅋㅋㅋ 이게 다큐인가..영화는 영화로 봅시다ㅋㅋ 이 전투를 이겼다니.. 이제와서 장군님이 얼마나 대단한 분이였는지를 알게되었습니다. 펄ㅡ럭'],
#        dtype='<U97'),
#  array(['명량', '8',
#         '7년동안 완전히 보지 않아서 지금 봤다. 최민식 연기는 두말할 건 없다. 전투신은 정말 재미있게 봤다. 그런데 뭔가 아쉬운 부분이 존재해서 8점'],
#        dtype='<U80'),
#  array(['명량', '7',
#         '민족의 영웅이자 성웅이신 이순신 장군님이 이 영화의 주제이기때문에 좀더 조금만 더 잘 만들어졌으면..하는 실망감이 들었지만 다음에는 이순신장군님을 소재로 한 더 좋은 퀄리티의 영화를 기대해볼 수 있는 첫걸음으로는 높게 칭찬한다. 영화개봉 당시의 우리나라 내정이 시끄러웠기 때문에 더 기대를 했었던...'],
#        dtype='<U168'),
#  array(['명량', '1',
#         '진짜 유치하다. 이순신은 인생 자체가 영화인데 뭐 이런 삼류 유치뽕짝을 만들어놨냐.진짜 보다가 화가 다 나네.'],
#        dtype='<U61'),
#  array(['명량', '2', '뭐 이런게 전체관람객 1위냐'], dtype='<U15'),
#  array(['명량', '4',
#         '이순신 장군을 스크린에서 볼 수 있다는 것은 좋았으나 영화의 완성도는 상당히 낮습니다 같은 감독이 후속편을 준비중이라는데 후속편은 애국마케팅 말고 완성도로 승부해 주세요~'],
#        dtype='<U95'),
#  array(['명량', '1', '이딴 쓰레기에 이순신장군 팔아쳐먹지 마세요 진짜 양심도 적당히 없어야지'], dtype='<U39'),
#  array(['명량', '8',
#         '명량이 욕먹는 이유는 스크린 독점때문이지 영화 자체적으로 크게 욕할만한 부분은 없었음. 최민식 배우 연기도 좋았고 전투씬도 훌륭하게 그려냈고 기존에 알던것 보다 실제 명량대첩에 대해 좀 더 역사 기록적으로 그려낸 점도 있고 평가를 좋게 해줄만함.'],
#        dtype='<U137'),
#  array(['명량', '10', '이게 벌써 2014년 영화란게 안믿긴다...'], dtype='<U24'),
#  array(['명량', '10', '이게 벌써 2014년 영화란게 안믿긴다...'], dtype='<U24'),
#  array(['명량', '10', '한국사람이라면꼭봐야함최고의영화 가슴이웅장해지는것을느낌.'], dtype='<U30'),
#  array(['명량', '6', '억지 국뽕. 이순신 장군은 위대하지만 이 영화는 절대 재미있는 영화는 아니다'],
#        dtype='<U42'),
#  array(['명량', '10', '보는내내 심장이 뛰었습니다잊지못할 영화'], dtype='<U21'),
#  array(['명량', '9',
#         '14.08.03.항상 온화하고 따뜻한 인상이 아닌, 전쟁을 겪으며 서린 노기와 냉철함, 그리고 투지까지 갖춘 최민식의 이순신은 가슴을 울렸다.잘생긴 김명민의 이순신과는 다른. 하지만 나쁘지 않았던.'],
#        dtype='<U110'),
#  array(['명량', '8', '영화에 대해 잘 모르는 사람이 단순 재미도만으로 주는 평점입니다'], dtype='<U35'),
#  array(['명량', '10',
#         '영화 300의 조선버전이순신 장군이 왜 성웅으로 불리는가에 대한 극적 묘사가 잘 드러남. 인생영화 중 하나'],
#        dtype='<U59'),
#  array(['명량', '4',
#         "이거랑 '암살'이랑 주변에 재밋다는 사람 한번도 못봣지만 인터넷과 매체에서만 난리인 이상한 영화.솔직히 욕먹어야한다. 이런 영화들에 대중들 실망하기 시작하면 막상 좋은 한국영화 나와도 믿질 못한다. 지들만 한번 뽕뽑고 재미 보면 다인가? 영화인으로써 책임감도 없나. 자신있음 속편도 내봐. 누가보나"],
#        dtype='<U166'),
#  array(['명량', '10',
#         '확실한건 실화라는게 팩트 영화보다 더영화같은 기적을 만드신 분이시다. 비현실적이다 하는 애들은 도대체가…'],
#        dtype='<U58'),
#  array(['명량', '10', '지금 전쟁이 나면 누가 저렇게 싸울수있을지'], dtype='<U23'),
#  array(['명량', '10', '제 인생 영화입니다 최고에요!'], dtype='<U16'),
#  array(['명량', '10', '이순신의 위대함을 보여준 한국영화 탑5 안에 든 엄청난 영화 라고 생각 합니다.'],
#        dtype='<U44'),
#  array(['명량', '10', '이순신장군님. 안녕하세요.'], dtype='<U14'),
#  array(['명량', '10', ''], dtype='<U2'),
#  array(['명량', '2', '말도 안되는 전투장면, 수준이하의 영화'], dtype='<U21'),
#  array(['명량', '10', '재밌게 잘 봤습니다 역시 최민식의 연기는 일품이군요'], dtype='<U28'),
#  array(['명량', '10', '넘 재밌게 봤어요 ㅠ이순신 장군님 ….'], dtype='<U21'),
#  array(['명량', '10', '최민식 님 연기력 뛰어납니다 ...한국 최고의 영화 감동 감동 짝짝짝 짝'],
#        dtype='<U40'),
#  array(['명량', '10', ''], dtype='<U2'),
#  array(['명량', '10',
#         'Ebs 에서 8.15 광복절이라고 해주는데, 감회가 새롭네요.나라를 위한 충신이 있는 나라..살만하지 않나요..'],
#        dtype='<U62'),
#  array(['명량', '10',
#         '두려움을 용기로 바꿀수 있다면 백배 만배의 힘을 모을수 있다는 교훈을 보여준 지혜에 감사드립니다'],
#        dtype='<U53'),
#  array(['명량', '10', '이걸 보고 재미없다고 하면 한국사람이 아닌거지. 감동+연기력 모두 좋구만'],
#        dtype='<U40'),
#  array(['명량', '10', '감동적인 영화네요 ㅎㅎ'], dtype='<U12'),
#  array(['명량', '10', '너무 감동적인 영화보는내내 울컥하고..눈물이...ㅜㅜ'], dtype='<U29'),
#  array(['명량', '1',
#         '이순신 장군의 위대한 업적을 상업적으로 흥행 된 영화 어렸을 때 불멸의 이순신 드라마가 천만배 훨 재밌음'],
#        dtype='<U58'),
#  array(['명량', '1', '진짜 국뽕빼면 볼게없는 영화 보다가 숙면 쌉가능'], dtype='<U26'),
#  array(['명량', '10',
#         '볼때마다 국뽕이차오름, 눈물샘 자극하는 곳도있고, 한번쯤은 꼭 봐야만하는 영화. 충무공 존경합니다'],
#        dtype='<U54'),
#  array(['명량', '10',
#         '볼때마다 뽕이차오름, 눈물샘 자극하는 곳도있고, 한번쯤은 꼭 봐야만하는 영화. 충무공 존경합니다'],
#        dtype='<U53'),
#  array(['명량', '1', '아니 이게 왜 천만영화야... 진짜 개재미없음...ㄹㅇ...'], dtype='<U33'),
#  array(['명량', '10',
#         '이순신장군님을 좋아하는 아들 덕분에오랫만에 한번 더 보았네요울 아가가 이순신장군을 너무 좋아해요!우리나라를 지켜주셔서 감사합니다^^'],
#        dtype='<U73'),
#  array(['명량', '10', '내가 이걸 왜 이제 봤을까…. 개멋지다 진짜로..'], dtype='<U27'),
#  array(['명량', '2',
#         '왜구 배와 3:1로 백병전 뜨는거보고 어처구니없어서 걍 끔걍 국뽕으로 좀비떼마냥 사람동원한 킬링타임으로도 짜증나는 영화'],
#        dtype='<U66'),
#  array(['명량', '10',
#         '8년 만에 다시 너무 떠올라서 다시 봤습니다..처음 볼땐..와아 그래픽 좋다..고증 뛰어나다(우리도 이 정도의 영화가 만들어지는구나)로 작품을 접했는데...나름 세상을 조금 넓게 알고 나니...인물들의 감정라인과...이해관계 등이 보이면서 모든게 완벽한 제 인생 최고의 영화였네요...감사합니다'],
#        dtype='<U164'),
#  array(['명량', '10',
#         '8년 만에 다시 너무 떠올라서 다시 봤습니다..처음 볼땐..와아 그래픽 좋다..고증 뛰어나다(우리도 이 정도의 영화가 만들어지는구나)로 작품을 접했는데...나름 세상을 조금 넓게 알고 나니...인물들의 감정라인과...이해관계 등이 보이면서 모든게 완벽한 제 인생 최고의 영화였네요...감사합니다'],
#        dtype='<U164'),
#  array(['명량', '10', '잊을 수 없다. 차수약제 사즉무감'], dtype='<U18'),
#  array(['명량', '10', '잊을 수 없다. 차수약제 사즉무감'], dtype='<U18'),
#  array(['명량', '10', '이제야 이 명장을 봤다니더 일찍 볼껄'], dtype='<U20'),
#  array(['명량', '4',
#         '위기와 긴장이 해소될때마다 싼마이스럽게 나오는 영웅적인 음악과 연출, 개성없고 정체성 뚜렷한 빌런과 이에 맞서는 영웅, 진짜 부제를 캡틴 코리아로 지어도 될듯..액션씬은 대박이지만, 진짜 이순신 같이 훌륭한 소재와 최민식 같은 명배우로 이딴 싼마이 영화를 찍어내서 다음에 같은 주제로 더 훌륭한 영화를 만들수 있는 기회비용을 날려버린 죄를 용서치 못하겠음..외국유튜버 리뷰도 조금 cheesy 하지만 액션신은 훌륭하다 하더라. 정말 이게 역대 한국영화 흥행1위라는게 참 그렇다..'],
#        dtype='<U268'),
#  array(['명량', '10', '한번쯤 봐야할 영화입니다'], dtype='<U13'),
#  array(['명량', '2', '이런 작품이 흥행순위 1순위라는건 아직 갈길이 멀다는 반증이지.'], dtype='<U35'),
#  array(['명량', '10', '해상전투씬 너무 멋있었음...ㅠㅠ'], dtype='<U18'),
#  array(['명량', '10', '해상전투씬 너무 멋있었음...ㅠㅠ'], dtype='<U18'),
#  array(['명량', '10', '이순신 장군님 감사합니다!'], dtype='<U14'),
#  array(['명량', '4', '왜 쪽바리들 배는 포탄을 한번 안쏘냐? 총만 쏘고... 배를 너무 만들어서 가난해졌냐?'],
#        dtype='<U48'),
#  array(['명량', '6',
#         '이순신 장군의 위대함을 표현하기 위해 이순신 장군을 제외한 모든 사람들이 비겁하고 나쁘다고 묘사할 필요는 없었을 듯. 이순신 장군을 존경해 그를 따르는 부하 장수들도 많았을텐데 이 영화는 이순신 장군 대 나머지 모든 사람 구도인 느낌. 그래도 일본놈들 깨부술때는 무지 통쾌했음.'],
#        dtype='<U155'),
#  array(['명량', '10', ''], dtype='<U2'),
#  array(['명량', '10', '두번보니까 처음봤을때 못느낀 감정들이 올라온다 놓친장면들도 보이고 꼭 두번보길!'],
#        dtype='<U44'),
#  array(['명량', '2',
#         '쯧 불쌍한 영화....이건 내용이 별로 없고 무순 소린자도 하나도 모르겠습니다 아휴 불쌍해서...그래도 울 아빠가 추천했으니...볼 수 밖에...그래도 직원들이 고생했으니까2좀이라도 주지...잘 해 보세요 힘내세요!'],
#        dtype='<U120'),
#  array(['명량', '10',
#         '스토리연기자들의 표현력영화전반적인 감동과 재미로 역시 천만관객베스트 명품영화감사합니다 잘 봤고 소장가치가 있어요'],
#        dtype='<U62'),
#  array(['명량', '10', '빨리 속편 나왔으면 좋겠어요!!!! 최고!'], dtype='<U23'),
#  array(['명량', '10', '조음조음조츰조음조음'], dtype='<U10'),
#  array(['명량', '10', '좋은 영화인 것 같아요! 그냥 너무 멋있고..뭔가 네...'], dtype='<U32'),
#  array(['명량', '10', '너무잘봤습니다 킹순신장군님♡'], dtype='<U15'),
#  array(['명량', '10', '감사합니다! 우리 조상들 그리고 이순신 장군님!!!! 열심히 살겠습니다!'],
#        dtype='<U40'),
#  array(['명량', '10', '쥑인다 소ㅇ오로르르름'], dtype='<U11'),
#  array(['명량', '10', '쥑인다 소ㅇ오로르르름'], dtype='<U11'),
#  array(['명량', '3',
#         '대한민국 국민들한테 존경하는 인물 top3 뽑으라그러면 무조건반사로 튀어나오는 두 명이 이순신하고 세종대왕인데 그 치트키를 가지고 표팔이로 써먹는다는게 어이가 없음.반일국뽕 빼면 사실상 500만도 못 넘길 영화인데 이순신 버프랑 최민식연기로 최소 1500만은 먹었음.이순신 활약상을 보고싶으면 차라리 이런 픽션영화보지말고 그냥 다큐멘터리를 보던가 아니면 진짜 불멸의 이순신 보셈 그게 훨씬 나음'],
#        dtype='<U220'),
#  array(['명량', '10',
#         "해군을 꿈꾸는 난 보면서 계속 '내가 과연 전쟁 중에 이순신 장군님처럼 옳은 명령을 내릴 수 있을까?' 라고 생각했다. 한번쯤 또 보고 싶은 영화다."],
#        dtype='<U83'),
#  array(['명량', '1', '이런 졸작도 이렇게 흥행이 된다는게 너무 신기함'], dtype='<U26'),
#  array(['명량', '10', '여태 본 영화 중 가장 인상깊었던 영화였던 것 같아요'], dtype='<U29'),
#  array(['명량', '8', '다른 건 좋은데 화면 톤이 옛날 영화 같다. 한산 만들깬 요즘 영화처럼 세련된 영상을 기대함.'],
#        dtype='<U52'),
#  array(['명량', '4', '알바들 때문에 이제 리뷰 남김....참으로 지루한 슬로우모션의 향연....'],
#        dtype='<U41'),
#  array(['명량', '1',
#         '성웅 이순신은 존경받아 마땅한 위인임이 분명하나 명량이라는 이 영화는 그 위대한 위인께 누를 끼치는 저렴한 감성팔이상업영화에 불과 하다고 생각합니다. 걍 돈 쳐긁어모을려고 우리의 위대한 충무공 이순신을 이용해 먹은 것이지요. 후반부 벙어리 마누라고 으어억 소리지르면서 거적대기 휘두르는 장면은 진짜 아오.... 후속작 노량은 또 어떻게 조져놓을지 기대가 됩니다. 물론 전 보지 않을거지만요.'],
#        dtype='<U218'),
#  array(['명량', '7',
#         '역사 영화에서의 백성들은 보통 위인을 돋보이도록 하는 매개체로 쓰이는데 “명량”은 이순신 장군에게 일방적으로 보호받거나 구해지는 나약한 백성들이 아닌 장군이 위험에 처했을 때 도움을 줄 수 있는 자발적인 모습으로 표현된 것이 인상 깊었고 좋았던 것 같습니다.하지만 아쉬웠던 점도 있었습니다. 첫 번째는 이순신 장군의 내적 갈등이나 가치관을 깊게 다루지 않았다는 점입니다. 영화에 나오는 이순신 장군의 그 짧은 대사나 장면들이 이미 대중들에게 널리 알려져 있었던 이미지나 명대사에 집중한 것 같다고 느꼈습니다. 물론 명대사를 넣었다는 점 자체가 아쉬웠다는 것은 아닙니다. 다만 이순신 장군이 그 승산 없는 전투에 나가기까지 얼마나 치열하게 고민했는지, 어떤 가치관을 지녔는지, 그리고 전투에 앞서 어떤 기분을 느꼈는지 등이 잘 표현되었다면 더 좋았을 것이라고 생각되어 아쉬웠던 것 같습니다. 두 번째는 인물 소개가 충분히 되지 않았다는 점입니다. 명량을 보면서 영화내용을 이해하고 스토리를 풀어 나가는데 중요한 역할을 하는 등장인물들이 저에게는 많았습니다. 그런데 전투 장면에 주로 초점을 맞추다보니 인물 소개가 충분히 되지 않았고 이름 정도만 보여주고 장면이 휙휙 지나가다보니 인물에 대한 이해도가 떨어져 처음 봤을 때는 누가 누구인지 잘 모르겠다고 느껴져서 그 점이 아쉬웠던 것 같습니다.영화 "명량"은 악한 상황 속에서도 포기하지 않는 불굴의 의지를 보이고 자신도 두려움을 느끼겠지만 장군들과 수군들에게 죽음이라는 두려움을 용기로 바꿔주기 위해 솔선수범 행동하고 어떤 상황에도 좌절하지 않고 도전하고 나 자신보다 군사들을 먼저 챙기는 이순신 장군의 리더십을 잘 표현하였고 저는 이 영화의 이순신 장군의 모습을 보고 그 리더십을 본받아 실천할 수 있는 제가 되도록 노력해야겠다고 느끼게 해준 영화였습니다. 감사합니다.'],
#        dtype='<U906'),
#  array(['명량', '8', '나쁘지 않다. 몰입해서 영화를 즐기게 해준다'], dtype='<U24'),
#  array(['명량', '7',
#         '이 영화 덕분에 막연히만 알고있던 이순신 장군님에 대해 찾아보고 제대로 알게되어 뜻 깊었네요. 다만 영화 자체는 마지막에 나오는 전투를 제외하면 재미는 없었어요. 자꾸 감동을 주려고 하는데 딱히 몰입이 되지않는 느낌이랄까요... 잘 만든 것 같은데 뭔가 많이 아쉬웠어요'],
#        dtype='<U150'),
#  array(['명량', '10', ''], dtype='<U2'),
#  array(['명량', '10', '너무 멋진 영화 감동 할 수 밖에 없는 영화'], dtype='<U24'),
#  array(['명량', '10', '아빠말 듣길 잘함 10점 만점에 10점'], dtype='<U21'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10', '개웃기네요. ㅋㅋㅋㅋ 덕붓에 미친듯이 웃었네'], dtype='<U24'),
#  array(['극한직업', '10', '재미있음재미있음재미있음재미있음'], dtype='<U16'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '2', '그냥 웃기려고 환장한듯한 오바연기…디테일 허술..'], dtype='<U27'),
#  array(['극한직업', '10', '진짜 뻥 안치고 내용 다 아는데도 다시봐도 ㅈㄴ 웃김 ㅋㅋㅋㅋ'], dtype='<U34'),
#  array(['극한직업', '10', '너무 웃겨요 진짜 또 보고 싶은 영화'], dtype='<U20'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '9', '처음부터 끝까지 쉴새없이 웃겨요'], dtype='<U17'),
#  array(['극한직업', '10', '항상 봐도 항상 웃기는 영화'], dtype='<U15'),
#  array(['극한직업', '1',
#         '첫째 명량 둘째 7번방에 이어 거품 쓰렉이 3대장의 막내. OO 같은 개그 코드에 할말을 잃었음.. 한국 흥행 코메디의 절망을 맛보고 싶다면 이 영화를. 희망을 보고 싶다면 최근 영화인 엑시트를 추천함'],
#        dtype='<U112'),
#  array(['극한직업', '10', '그냥보세요~최고입니다'], dtype='<U11'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10', '다시봐도 재미있네요. 다들 연기를 잘하시는듯'], dtype='<U24'),
#  array(['극한직업', '10', '다시봐도 재미있네요. 다들 연기를 잘하시는듯'], dtype='<U24'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '7', '막판에 현실성 없는 설정이 아쉽지만 근래에 본 영화주에 가장 웃을 수 있었던 것 같다'],
#        dtype='<U47'),
#  array(['극한직업', '7', '이병헌 감독이 화가나서 만든 영화 같다'], dtype='<U21'),
#  array(['극한직업', '1', '극한의 직업을 니들은 아냐?짱께집에서 뜨거운 불 맞딱뜨리면서 땀 흘리는게 극한인겨?ㅋㅋㅋㅋ'],
#        dtype='<U50'),
#  array(['극한직업', '10',
#         '홍진경이하는 영화소개? 거기서 다시 보게됐는데 너무재밌었던 기억이나고 다시봐도 푸하하 웃게되는 영화예요. 그리고 나오는 배우들이 다 자기역할에 너무 찰떡같고 다들 호감이예요. 아저는 전남편입니다. 그부분에서 미친듯이 웃었네요.'],
#        dtype='<U126'),
#  array(['극한직업', '3', '생각만큼 재밌지는않음'], dtype='<U11'),
#  array(['극한직업', '9', '처음부터 끝까지 완벽한 코믹의 구성 ! 한국 코믹영화의 표본'], dtype='<U33'),
#  array(['극한직업', '6', '초중반까진 정말 재밌는데, 이후로 힘이 쭉쭉 빠진다.'], dtype='<U29'),
#  array(['극한직업', '2', '도대체 이딴 영화가 왜 흥행이 되는건지 참'], dtype='<U23'),
#  array(['극한직업', '10', '재밌게본 한국영화 였습니다!'], dtype='<U15'),
#  array(['극한직업', '1', 'OO 이게 9.2점 1600만관객ㅋㅋㅋ 진지하게 한국영화수준 심각하다'],
#        dtype='<U38'),
#  array(['극한직업', '10',
#         '맨날 영화관에서 자는게 일이었는데 처음부터 끝까지 깔깔깔 터지며 봤던 영화. 재탕 삼탕 하는거 드문 내가 주기적으로 혈중 극한직업 농도 채워줘야 하는 영화. 한국 코미디의 원탑이라 꼽을 수 있다. 가끔 제목이 기억안나서 수원왕갈비 통닭이라고 부르지만...ㅋㅋㅋ'],
#        dtype='<U145'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10',
#         '아무생각없이 재밌게 보기 좋은 영화!!다시보니 더 재밌는 코믹액션 영화ㅎㅎ액션연기와 함께 대사하나 놓치지 않으려는 배우들의 연기에 박수친다'],
#        dtype='<U77'),
#  array(['극한직업', '10',
#         '아무생각없이 재밌게 보기 좋은 영화!!다시보니 더 재밌는 코믹액션 영화ㅎㅎ액션연기와 함께 대사하나 놓치지 않으려는 배우들의 연기에 박수친다'],
#        dtype='<U77'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10',
#         '극장에 가서 돈주고 웬만하면 한번 이상 잘안보는데 두번째가서 봤는대도 재미있어서 한참 웃다가 나온 영화입니다ㅎ'],
#        dtype='<U61'),
#  array(['극한직업', '10', '흥행이 최고점이었네요. 유쾌한 스토리 ...'], dtype='<U24'),
#  array(['극한직업', '10', '신선하다. 연기좋고 연출이 인상적'], dtype='<U18'),
#  array(['극한직업', '4', '아~ 재미없어'], dtype='<U7'),
#  array(['극한직업', '10', '너무 웃겨서 울었어요 예능보다 더 웃겨요이병헌 감독님 대박입니다'], dtype='<U35'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '9', '한국영화 핵심요약집'], dtype='<U10'),
#  array(['극한직업', '10', '코미디 안좋아하는데도 재밌게 봄.'], dtype='<U18'),
#  array(['극한직업', '5', '코믹은 그저 그렇고 액션은 쓸만하던데'], dtype='<U20'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10', '치킨 먹으면서 가족들과 재미있게 봤어요.'], dtype='<U22'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10', '대사도 웃기고 너무 재밌음'], dtype='<U14'),
#  array(['극한직업', '10', '재미재미재미재미존잼'], dtype='<U10'),
#  array(['극한직업', '10', '진짜 너무 웃김 ㅎ 맘 생각없이 보기 딱!'], dtype='<U23'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '8', '경찰코미디의 패시브인 허세가 여전히 오그라들긴 했지만 손에 꼽힐 정도로 재밌었음'],
#        dtype='<U44'),
#  array(['극한직업', '10', '웃고 싶을 때 찾게 되는 영화'], dtype='<U16'),
#  array(['극한직업', '10', '뻔한 영화지만, 뻔한 영화가 뽑아낼수 있는 최고의 품질.'], dtype='<U31'),
#  array(['극한직업', '10', '보고또봐도재밌네ㅋㅋㅋ'], dtype='<U11'),
#  array(['극한직업', '10',
#         '이병헌 감독님…배우분들 다 너무 감사합니다…제 인생 최고의 영화를 만들어주셔서 너무 감사해요..정말 영화관에서 처음 봤을 때에 그 신선한 충격은 아직도 잊혀지지 않아요. 단 한순간도 웃지 않을 수가 없는 장면들과 탄탄한 스토리와 전개와 영상미 이 모든 게 이렇게 완벽하게 왕갈비통닭처럼 버무려져서 정말 이 세상 최고의 영화가 나온 것 같아요!! 진짜 감독님 너무 감사하고요 이 영화를 수십번 봤고 대사까지 다 외웠는데도 언제봐도 너무 재밌고 행복합니다. 제 인생 영화를 만들어주셔서 감사합니다!! 극한직업 짱짱!!!!'],
#        dtype='<U289'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '10', '봐도 봐도 안 질려요~^^하늬씨 진국!!'], dtype='<U22'),
#  array(['극한직업', '10', '몇 번을 봐도 재밌어요 ㅋㅋㅋ'], dtype='<U16'),
#  array(['극한직업', '10',
#         '한국영화의 교과서. 솔직히 한국이라는 나라에서 화려한 액션을 기대하긴 힘드니까 코믹하면서도 배우들의 연기가 빛나는 영화가 살아남는데 그게 바로 극한직업.. 각본도 감독도 배우도.. 너무 좋았던 영화.'],
#        dtype='<U111'),
#  array(['극한직업', '10', '영화로써의 코미디의 끝을 보여줬다.예고편도 안보고 갔다가 배꼽빠지고 나온 영화'],
#        dtype='<U43'),
#  array(['극한직업', '10', '영화로써의 코미디의 끝을 보여줬다.예고편도 안보고 갔다가 배꼽빠지고 나온 영화'],
#        dtype='<U43'),
#  array(['극한직업', '10', '영화로써의 코미디의 끝을 보여줬다.예고편도 안보고 갔다가 배꼽빠지고 나온 영화'],
#        dtype='<U43'),
#  array(['극한직업', '10', '이 재밌는걸 인자 봤네ㅋㅋㅋㅋ 액션 코메디 너무 좋습니다'], dtype='<U31'),
#  array(['극한직업', '10', '극장에서 보고 집에서도 또 봅니다. 그런데도 재밌네요.'], dtype='<U30'),
#  array(['극한직업', '10', '기대안하고 봤는데, 처음부터 끝까지 웃으면서 봤다.'], dtype='<U28'),
#  array(['극한직업', '1', '..한국영화의 한계.'], dtype='<U11'),
#  array(['극한직업', '10',
#         '그냥 한국영화 레전든데 최근 평점까지 이악물고 비추 누르는놈들은 대체 뭐냐?ㅋㅋㅋ 눈깔이 없는건지 뇌가 없는건지 왜 남들이 재밌다고 하는거 반대하면 뭔가 있어보이고 그러냐? 막 지 혼자만 다른거같고 특별한거같음? 그냥 사회부적응자인걸 애써 포장하지마라'],
#        dtype='<U140'),
#  array(['극한직업', '10', '아 진짜 재밌어요 ㅋㅋ 두번째도 재미있게 봤어요'], dtype='<U26'),
#  array(['극한직업', '10', '여러번 다시 봐도 재미있어요'], dtype='<U15'),
#  array(['극한직업', '10',
#         '이거 2 안나와요?ㅜㅜ진짜 최고의 오락영화 가족영화 코믹액션영화임ㅠㅠ 관객수 기록에 거품 없는 몇 안 되는 영화라고 생각함 극장에서도 봤고 티비나 넷플로도 가끔 보는데 항상 웃기고 재미짐'],
#        dtype='<U104'),
#  array(['극한직업', '10', '대체불가 대한민국의 조미료 맛있게 넣은 김치찌개 같은 영화 ㅋㅋㅋ'], dtype='<U36'),
#  array(['극한직업', '1', '이런 영화가 흥행한 거 보면 세상이 만만한데.'], dtype='<U25'),
#  array(['극한직업', '10',
#         '영화 딱 처음 봤을 때 너무 웃겨서 배가 아팠는데 두 번째 봤을 때는 배가 아플 정도로 웃기지는 않았다'],
#        dtype='<U57'),
#  array(['극한직업', '10', '재미나네요 정말이요 ㅎㅎ'], dtype='<U13'),
#  array(['극한직업', '10', '내가 본 코미디영화중 단언컨대 최고였다고 생각합니다'], dtype='<U28'),
#  array(['극한직업', '10', '진짜 ㅋㅋㅋ이것보다 웃긴 영화늨 본적이 없다 다시봐도 개웃기다 ㅋㅋ'],
#        dtype='<U37'),
#  array(['극한직업', '1', '이런 영화들이 안나와야 합니다.'], dtype='<U17'),
#  array(['극한직업', '10', '진짜 몇번을 돌려봐도 재밌는 영화,, 구석구석 센스없는 곳이 없고 버릴게 없는 영화 같아요'],
#        dtype='<U50'),
#  array(['극한직업', '10', '코메디 영화 중 최고 최애작입니다'], dtype='<U18'),
#  array(['극한직업', '10',
#         '한국영화중에 최애 3개 중 1개. 극한직업. 친절한금자씨. 웰컴투동막골! 이 3개는 몇번을 봐도 안질리고 좋음,,'],
#        dtype='<U63'),
#  array(['극한직업', '10', 'ㅋㅋㅋㅋ다시 봐도 너무 웃기다'], dtype='<U16'),
#  array(['극한직업', '10', 'ㅋㅋㅋㅋ다시 봐도 너무 웃기다'], dtype='<U16'),
#  array(['극한직업', '10', 'ㅋㅋㅋㅋ다시 봐도 너무 웃기다'], dtype='<U16'),
#  array(['극한직업', '10', ''], dtype='<U4'),
#  array(['극한직업', '6', '하아.. 명성에 속았다. 일단 연기력이 다들 너무 떨어져. 재미 없음.'],
#        dtype='<U39'),
#  array(['극한직업', '10', '극한직업 나올 당시부터 기대했었는데 너무 재밌음...'], dtype='<U29'),
#  array(['극한직업', '8', '이라싸이마쌩!! 짝짝'], dtype='<U11'),
#  array(['극한직업', '10', '웃고 싶을때마다 보는데 매번 웃기는 최애 영화.'], dtype='<U26'),
#  array(['극한직업', '7', '영화에 대해 잘 모르는 사람이 단순 재미도만으로 주는 평점입니다'], dtype='<U35'),
#  array(['극한직업', '10', '봐도봐도 너무 재미있는 영화♡♡♡'], dtype='<U18'),
#  array(['극한직업', '2', '나 조선족 아님. 그냥 안웃김.'], dtype='<U17'),
#  array(['극한직업', '2', '와 이게 재밌다니 수준 충격적... 재밌지도 참신하지도 감동적이지도 않았음'],
#        dtype='<U41'),
#  array(['극한직업', '10',
#         '원래 코믹영화 잘안보는편인데 이 영화는 억지웃음짓게 하는게 아니라 찐으로 웃겼네요ㅎㅎ 요새 웃을 일 잘없었는데 영화 내내 거의 쉬지도 않고 웃었던거같아요~그동안 안봤던게 후회될정도. 잘봤습니다'],
#        dtype='<U107'),
#  array(['극한직업', '10', '진짜 많이 웃으면서 봤습니다. 단순하게 정말 웃겼어요!'], dtype='<U30'),
#  array(['극한직업', '10', '한국 코메디 웰메이드 명작'], dtype='<U14'),
#  array(['극한직업', '7', '매력적인 캐릭터들은 많지만 코미디인걸 감안해도 너무 정신이 없다.'], dtype='<U36'),
#  array(['극한직업', '5', '초반은 그래도 웃기는 장면이 몇 있는데 중후반되니 엉성한 3류 범죄물로 전락'],
#        dtype='<U42'),
#  array(['극한직업', '10', '패는것보다 묶는게 더힘드네 도와주세요'], dtype='<U20'),
#  array(['극한직업', '8', '고급식당은 아니지만 깔끔하게 맛있는 프랜차이즈 치킨느낌'], dtype='<U30'),
#  array(['극한직업', '6',
#         '초중반까지 코믹을 재치있게 잘버무려 즐겁게 감상했습니다. 후반부의 식상함이 매력을 반감시키네요. 그래도 볼만한 코믹영화'],
#        dtype='<U66'),
#  array(['극한직업', '2', '이게 천만인거 실화냐존나재미없다'], dtype='<U17'),
#  array(['극한직업', '8', '신하균 오정세 때문에 재밌었던 기억이~~~2021'], dtype='<U27'),
#  array(['신과함께-죄와 벌', '1', '솔직히 재밌나???ㅜ 이게 천만을 넘었다니 믿겨지지가않네ㅜㅜ아우 오글오글거려'],
#        dtype='<U42'),
#  array(['신과함께-죄와 벌', '10',
#         '작품이 지닌 고유의 스토리를 영상미로 극대화 하려다 보니, 그에 못지 않게 중요한 스토리가 균형있게 드러내어지지 못한 작품.'],
#        dtype='<U69'),
#  array(['신과함께-죄와 벌', '10',
#         '오랜만에 집에서 혼자 봤는데 진짜 눈물콧물 다 흘리면서 울었어요... 마지막에 어머니가 자홍이의 마음을 다 아셨다는 사실... 특히 현몽에서 어머니가 수홍이 손을 잡으며 너희 잘못 없다고 말하고 이름을 불러주실 때 진짜 오열했습니다....'],
#        dtype='<U133'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '9', '너무 재밌고 울 뻔 했어요ㅠㅠ 재밌당.'], dtype='<U21'),
#  array(['신과함께-죄와 벌', '9', '너무 재밌고 울 뻔 했어요ㅠㅠ 재밌당.'], dtype='<U21'),
#  array(['신과함께-죄와 벌', '7',
#         '이 영화보면서 느낀점 1. 개똥밭에 굴러도 이승이 저승보다 100만배 낫다2. 우리 가족이 불교여서 나도 불교인데 기독교로 바꿔야되나 순간 생각듬 결론: 무교3. 영화가 그럭저럭(순간 지루해지는 장면(시간) 은근많음) 순간 울컥해서 우는 몇몇장면 있음 (본인 울었음) 그거 제외하곤 솔직히 그냥 저냥임 특별히 추천하고싶지는 않은 영화 참고로 웹툰 1도 안봤음 영화로 보면 그냥 저냥인데 웹툰이 훨재밌나?? 8점 주기엔 아닌것같고 6점 주기엔 그래서 7점 줌'],
#        dtype='<U255'),
#  array(['신과함께-죄와 벌', '10', '진짜..보고울었다...'], dtype='<U12'),
#  array(['신과함께-죄와 벌', '8', '재미있게 잘 봤어용.'], dtype='<U11'),
#  array(['신과함께-죄와 벌', '10',
#         '올만에 다시 보는데,,,,이건 대작이다.배우 캐스팅 완벽 ,,,,특히 자홍이어머니 연기력이 쫑'],
#        dtype='<U52'),
#  array(['신과함께-죄와 벌', '5',
#         '이 영화는Cg나 전체적인 영상미는 아주 좋았는데,그점은 정말 눈이 즐거웠고 만족함.근데 스토리가 처음부터 끝까지 계속 눈물만 찔찔짜는 신파극으로만 나감...마치 주인공이 세상에서 가장 불쌍하고 효심쩔고~ 서럽고 한많은지 알리려는 영화같음...눈물을 자극하는 장면이 2~3장면정도만 나와야 감동일텐데, 이 영화는 마치 처음부터 끝까지계속 ~~한도끝도없이 눈물만 짜내려고함이런 울보영화를 좋아하는걸보니 한국사람들이 참 감성적인가봄...좀 과대평가됀 영화같음'],
#        dtype='<U253'),
#  array(['신과함께-죄와 벌', '10',
#         '진짜 미쳤어요ㅠ 모든장면이 다 전율이 있고 그 전율이 관람객들을 울려요... 그리고 맨 마지막에너무 슬펐어요ㅠ'],
#        dtype='<U61'),
#  array(['신과함께-죄와 벌', '10', '신비함과 감동에서 벅차오른다!!!'], dtype='<U18'),
#  array(['신과함께-죄와 벌', '8', '18.01.13.딱히 국내 영화 치고는... 따위의 수식어구 없이도 정말 괜찮았다.'],
#        dtype='<U46'),
#  array(['신과함께-죄와 벌', '10', 'ㅠㅠㅠ 수홍이랑 엄마 대화하는 거에서 눈물광광 ㅠㅠ'], dtype='<U28'),
#  array(['신과함께-죄와 벌', '6', '스토리 별로..재미는 없고 열라 슬프기만 하네요.'], dtype='<U27'),
#  array(['신과함께-죄와 벌', '4',
#         '왠만하게 감동을 유도한 영화는 울기 마련이었는데 죄와벌은 정말 억지스러운 눈물 짜내기라는 게 심하게 다가와서 정말 별로였던 영화였다.'],
#        dtype='<U74'),
#  array(['신과함께-죄와 벌', '10', '밑에분..낙태지옥이 아니라 나태지옥입니다..;;'], dtype='<U26'),
#  array(['신과함께-죄와 벌', '9', '인과 연보다 죄와 벌을 더 재밌게 봤다'], dtype='<U21'),
#  array(['신과함께-죄와 벌', '2',
#         '지금까지 본 영화중에 제일별로임ㅋㅋㅋ 어거지 감동연출이랑 깨달음 일침 주려는 대사 눈살 찌뿌려짐'],
#        dtype='<U53'),
#  array(['신과함께-죄와 벌', '8', '영화에 대해 잘 모르는 사람이 단순 재미도만으로 주는 평점입니다'],
#        dtype='<U35'),
#  array(['신과함께-죄와 벌', '10', '진짜 정말 여러모로 레전드인 영화라고 생각합니다'], dtype='<U26'),
#  array(['신과함께-죄와 벌', '10', '진짜 정말 여러모로 레전드인 영화라고 생각합니다'], dtype='<U26'),
#  array(['신과함께-죄와 벌', '10', '눈물 다 뽑았다리...ㅠㅠ'], dtype='<U14'),
#  array(['신과함께-죄와 벌', '1',
#         '잘 봤어 근데.. 왜 다들 하나같이 연기가 어설프고 거슬리냐.. 이 감독이 찍는 영화는 다 그런 특징이 있지. 유치하고 그리고 늘 더럽고 구질구질한 감성팔이로 억지 인기를 강도질 하지.역겨운 짱깨영화만도 못하게 어색하고 한심해. 그래서 나는 앞으로 이 감독의 영화는 무조건 걸르거나 1점 이하만 줄 꺼야.'],
#        dtype='<U170'),
#  array(['신과함께-죄와 벌', '10', '.'], dtype='<U9'),
#  array(['신과함께-죄와 벌', '10', '너무 슬퍼서 많이 울었고 좋은영화 감사합니다'], dtype='<U24'),
#  array(['신과함께-죄와 벌', '1',
#         '신파덩어리. 원작을 본 사람으로써 영화판이 만화작가를 얼마나 무시하는지 느낌. 도대체 진기한은 왜 없어졌으며 차태현은 원작 김자홍이랑 하나도 안비슷함!!!'],
#        dtype='<U86'),
#  array(['신과함께-죄와 벌', '10', '울고 싶은 모든 이에게'], dtype='<U12'),
#  array(['신과함께-죄와 벌', '1', '신파 작렬 아직까지도 왜 이게 1000만 관객이 넘었는지 의문'],
#        dtype='<U34'),
#  array(['신과함께-죄와 벌', '1', '딴거 다떠나서 혜원맥 왜저따위로 캐릭터잡았냐'], dtype='<U24'),
#  array(['신과함께-죄와 벌', '10', '재밌게 봤어요 도경수도 연기 잘함 ㅋㅋ'], dtype='<U21'),
#  array(['신과함께-죄와 벌', '9', '아빠 이거보고 영화관에서 눈물흘리면서 훌쩍훌쩍거렸는데 너무 쪽팔렸음 ㅋㅋ'],
#        dtype='<U40'),
#  array(['신과함께-죄와 벌', '9', '아빠 이거보고 영화관에서 눈물흘리면서 훌쩍훌쩍거렸는데 너무 쪽팔렸음 ㅋㅋ'],
#        dtype='<U40'),
#  array(['신과함께-죄와 벌', '1',
#         '보는 내내 화가났음스토리나 연출이 뻔하고 유치한데다 컨셉은 온갖 짬뽕이라 이게 한국판타지? 라고 할 수 있는지 의문이었음 이정재는 간달프같았음그냥 돈 많고 빽 많은 감독이 자기 하고싶은거 다 해본 느낌원작의 세련된 설정이나 시나리오를 멋지게 살려줄 영화화를 다시 기대할 수 없다는 점이 슬프기까지 함'],
#        dtype='<U167'),
#  array(['신과함께-죄와 벌', '10', '이거 보고 쳐 울었다 존나 슬픔'], dtype='<U17'),
#  array(['신과함께-죄와 벌', '10', '시간 가는 줄 모르고 봤습니다'], dtype='<U16'),
#  array(['신과함께-죄와 벌', '10', '넘넘재밌어요 다시보는데도 최고~~'], dtype='<U18'),
#  array(['신과함께-죄와 벌', '4', '진부하고 눈물 짜내려고 노력하는 신파극'], dtype='<U21'),
#  array(['신과함께-죄와 벌', '1',
#         '이게 왜 재밌다는거임?? 이해를 하나도못하겠네웹툰 신과함께에선 각 지옥마다 설명과 왜 그런식의 벌을받는지 이유들이 다나오는데 영화는 그냥 여기가 뭐다 이게뭐다 하고 끝남 스토리에 내용이없음웹툰을 보고만든건지 이해할수도없고 웹툰안보고 본다해도 이해할수없는 스토리전개임.이게 대체 어떤부분에서 찬양을 받는거임??'],
#        dtype='<U172'),
#  array(['신과함께-죄와 벌', '10', '연기력에 만점 드립니다'], dtype='<U12'),
#  array(['신과함께-죄와 벌', '10', '연기력에 만점 드립니다'], dtype='<U12'),
#  array(['신과함께-죄와 벌', '10', '휴지는 필수입니다. 얼마나 많이 운지 모르겠어요 ㅠㅠ'], dtype='<U29'),
#  array(['신과함께-죄와 벌', '2', '원작 내용 왜 바꿨는지 모르겠음. 개노잼'], dtype='<U22'),
#  array(['신과함께-죄와 벌', '8', '다소 긴듯한 느낌은 있었지만 볼거리가 다양했다.'], dtype='<U26'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '2', '어머니! 어머니! 어머니!~~우에에엥~ 어머니~ 하다가 끝남'],
#        dtype='<U33'),
#  array(['신과함께-죄와 벌', '10', '즙짰습니다 개슬픕니다'], dtype='<U11'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '8', '연기력과연출력이훌륭하고 스토리가재미있었음'], dtype='<U22'),
#  array(['신과함께-죄와 벌', '8', '알면서도 울 수 밖에 없고, 펑펑 울었지만 가슴에 남는 건 없다.'],
#        dtype='<U36'),
#  array(['신과함께-죄와 벌', '2', '여기까지만 만들지....'], dtype='<U13'),
#  array(['신과함께-죄와 벌', '10', '재미있고 전개 좋고,,,웃으며 보다가 오열하고 이런 스타일 넘 좋아요'],
#        dtype='<U38'),
#  array(['신과함께-죄와 벌', '9', '재미 감동 잘 뽑은 영화'], dtype='<U13'),
#  array(['신과함께-죄와 벌', '10', '이 영화보고 눈물을 단 한방울 이라도 흘리지 않았다면, 당신은 싸이고패스입니다.'],
#        dtype='<U44'),
#  array(['신과함께-죄와 벌', '8',
#         '장르는 판타지지만 그안에 새로운것이 있고 정말 마지막이 반전이고 보면서 삶에대해 다시한번 느끼게되네요 영화보면서 울었습니다 어머니꿈에서 아들과 재회하는데 ㅠㅜ 진심 잘만들었네요 영화 뜻깊게보다갑니다'],
#        dtype='<U110'),
#  array(['신과함께-죄와 벌', '10',
#         'ㄷㄱ ㅇㅂ로 ㅅㅇㅇ 누르는 사람들 ㄱㅈㅈㅇ 문앞에서 걸릴 듯 ㅅㅇㅇ 누를 이유 없는 거 같은 ㄷㄱ들도 ㅅㅇㅇ 많네'],
#        dtype='<U63'),
#  array(['신과함께-죄와 벌', '10', '많은 생각을 하게되는 영화입니다.'], dtype='<U18'),
#  array(['신과함께-죄와 벌', '2', '김자홍은 OOO 세계관에서도 가장좋은 귀인인데지옥을 7번 갈뻔함ㅋ'],
#        dtype='<U36'),
#  array(['신과함께-죄와 벌', '10',
#         '영화가 굉장히 재밌고 모든 사람들의 연기가 좋다 슬픈 스토리까지 감동적이다. 너무 늦게 본 것 같다.'],
#        dtype='<U56'),
#  array(['신과함께-죄와 벌', '10', '눈물바다를 만들어줍니다'], dtype='<U12'),
#  array(['신과함께-죄와 벌', '10', '눈물바다를 만들어줍니다'], dtype='<U12'),
#  array(['신과함께-죄와 벌', '10', '그냥 띵작내가 본 영화중 가장 띵작'], dtype='<U19'),
#  array(['신과함께-죄와 벌', '10', '그냥 띵작내가 본 영화중 가장 띵작'], dtype='<U19'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '1', '평점 너무 높아서 낮추고 갑니다 원작을 망쳐놨음'], dtype='<U26'),
#  array(['신과함께-죄와 벌', '10',
#         '개봉할때 보고 두번째 보는대도 시간 가는 줄 모르고 재밌게 봤습니다. 한국 판타지 영화의 수작!'],
#        dtype='<U53'),
#  array(['신과함께-죄와 벌', '10',
#         '배우 모두의 좋은 연기가 cg를 어색하지 않게 했다.사후세계를 잘 나타내었고. 감동적이었다. 현재 삶을 잘 살아야 겠다는 교훈적인 영화이다.'],
#        dtype='<U78'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '8', '웹툰보고 봤는데 재밌었어요 잘봤습니다.'], dtype='<U21'),
#  array(['신과함께-죄와 벌', '9', '판타지 개 싫어 하는 나에게 재미를 준 수작입니다.'], dtype='<U28'),
#  array(['신과함께-죄와 벌', '6',
#         '세계 최고 스케일의 환타지 신파극. 억지 눈물 짜내기 안하면 영화 못만드나요. 배우들의 열연과 예전에 비해 놀랍게 발전한 CG/시각효과가 아까움.'],
#        dtype='<U81'),
#  array(['신과함께-죄와 벌', '2', '무슨 울기만 하면 모든 재판이 통과임;;'], dtype='<U22'),
#  array(['신과함께-죄와 벌', '2', '무슨 울기만 하면 모든 재판이 통과임;;'], dtype='<U22'),
#  array(['신과함께-죄와 벌', '2', '무슨 울기만 하면 모든 재판이 통과임;;'], dtype='<U22'),
#  array(['신과함께-죄와 벌', '1', '신파와 허술한 cg와 함께'], dtype='<U14'),
#  array(['신과함께-죄와 벌', '10',
#         '개봉당시 극장에서보고 오늘티비에서 재방하는거봤는데 진짜재밌네요 끝에 엉엉거리며울었어요 CG표시도안나고 진짜재밌게봤어요'],
#        dtype='<U65'),
#  array(['신과함께-죄와 벌', '10',
#         '신과함께-죄와 벌 이지옥 에서 7번째 이렇게 말하고 있습니다 오늘 제가 첨으로 본 글은 올립니다.억울하게 누명 당하고 있습니다. 한을 풀어서 그런지 콱하고죽더래 진짜 얼마나 시간이 너무 많이 해주세요 행복하세요 감사합니다 추워지니 감기에 걸리지 않도록 조심해야 합니다 건행하세요.'],
#        dtype='<U156'),
#  array(['신과함께-죄와 벌', '10',
#         '신과함께-죄와 벌 이지옥 에서 7번째 이렇게 말하고 있습니다 오늘 제가 첨으로 본 글은 올립니다.억울하게 누명 당하고 있습니다. 한을 풀어서 그런지 콱하고죽더래 진짜 얼마나 시간이 너무 많이 해주세요 행복하세요 감사합니다 추워지니 감기에 걸리지 않도록 조심해야 합니다 건행하세요.'],
#        dtype='<U156'),
#  array(['신과함께-죄와 벌', '1', '네이버평점 믿지마세요 유치뽕에 괜히 시간낭비했네 아놔'], dtype='<U29'),
#  array(['신과함께-죄와 벌', '7',
#         '만화틱하다. 대사며 연기며. 그래서 크게 와닿진 않는다 + 눈물을 자아내는 가족애에 대한 표현이 짙다고 해서 그게 작품성으로 이어지진 않는다고 생각. 10점을 주는 사람들은 객관적이지 않다'],
#        dtype='<U105'),
#  array(['신과함께-죄와 벌', '6',
#         '신파 함께... 근데 진짜 궁금한게 첫번째 재판에서 열심히 간이유가 돈이라고 김자홍이 말했잖아 그럼 돈때문에 열심히 살면 안되나 사람 죽이거나 그런 불순한 의도도 아닌데.... 왜 그 판관은 형때릴려고 했지?'],
#        dtype='<U116'),
#  array(['신과함께-죄와 벌', '10', '엄마 울릴라고 또 봤는데 정작 엄마는 안울고 오빠랑 나만 쥰내 울었다....'],
#        dtype='<U42'),
#  array(['신과함께-죄와 벌', '10',
#         '아 진짜 너무 재밌어요 어떻게 이런 스토리의 영화가 나오죠..옛날에 보고 또 보는중이요'], dtype='<U48'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '8',
#         '차태현은 역시 시종일관 진지한 연기는 안어울려 코믹을 같이 섞어서해야 진지한 연기빛이나는데 아무리봐도 차태현은 미스캐스팅 같아 내 주관적인 생각임'],
#        dtype='<U81'),
#  array(['신과함께-죄와 벌', '8',
#         '영화를 2번째로 봤는데 또 봐도 재밌고 그런 세계가 있으면 낙태지옥?에서 떨어질듯..'], dtype='<U47'),
#  array(['신과함께-죄와 벌', '9', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '10', '너무 재밌게 봤습니다 ^^*'], dtype='<U15'),
#  array(['신과함께-죄와 벌', '6', '다좋은데 다시보니 차태현 케릭터 말한마디 제대로 못하는 ㅂ.ㅅ 샤키네 답답한 새.키'],
#        dtype='<U46'),
#  array(['신과함께-죄와 벌', '10', '마동석 마지막장면 밖에 안나왓는데 천만관객 주연?ㄷㄷㄷ'], dtype='<U30'),
#  array(['신과함께-죄와 벌', '10', '인생작 눈물이 마르지 않네요 ㅠ 가슴을 울리는 명대사가 참 많아요'],
#        dtype='<U36'),
#  array(['신과함께-죄와 벌', '8', '머릿 속으로 다 예상가는 신파적인 스토리인데도 눈에서는 눈물이 줄줄줄'],
#        dtype='<U38'),
#  array(['신과함께-죄와 벌', '10', '연기력,CG 모두 훌륭했어요!별점 1개 주는 타영화 알바들 평점은 전부 무시하셈'],
#        dtype='<U44'),
#  array(['신과함께-죄와 벌', '10', ''], dtype='<U9'),
#  array(['신과함께-죄와 벌', '6',
#         '멋들어지게 구현한 "지옥 테마파크" 체험의 묘미와 삶의 보편적 가치들로 이끌어 내는 정서적 공감의 조화. \'신파\'에 대한 강박을 조금 덜어 냈더라도 충분히 울리고 남았을 텐데. 어쨌든, 흥미롭고 애처롭다.'],
#        dtype='<U114'),
#  array(['신과함께-죄와 벌', '1', '한국영화 특유의 오글거리는 신파씬이 난무하는 에휴'], dtype='<U27'),
#  array(['신과함께-죄와 벌', '1', '진짜 뭔 영화냐 캐스팅 빼곤 영양가가 하나도 엊ㅅ는 인스턴트 작품'],
#        dtype='<U36'),
#  array(['국제시장', '10',
#         '우리 할아버지 세대를 그린 영화 ㅜㅜ 지나고보니 다 그랬던 것 같다.. 근데 이 586세대는 뭐하는 사람들이지?'],
#        dtype='<U62'),
#  array(['국제시장', '8',
#         '전쟁통에 길 위에서 가족을 잃는다는 게 어떤 느낌일지 처음으로 느낌.간절히 보고 싶고 그리워하는 마음이 뭔지 간접적으로나마 느껴봤다.그들의 인생이 너무 썼던 것 같다.'],
#        dtype='<U93'),
#  array(['국제시장', '10', '내가 본 영화중에 제일 많이 운 영화'], dtype='<U20'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10',
#         '정말 감동적이네요 우리나라의 슬픈 역사를 토대로 만든 영화이다 보니 더욱 감동적이고 그에 가족의 사람과 인간이 생존하기 위한 절박함을 더해 재미있었습니다'],
#        dtype='<U85'),
#  array(['국제시장', '10',
#         '괜히천만영화가아닙니다. 코믹과감동그시대에아버지들 !!너무감동적이고재밌었어요!!!그리고유노윤호가나온줄몰랐네ㅋㅋ 오달수와황정민의연기가너무좋았어용^^'],
#        dtype='<U80'),
#  array(['국제시장', '10', '우리가 지금 있을 수 있는 이유'], dtype='<U17'),
#  array(['국제시장', '10', '볼때마다 자꾸 눈물이 나네요~~시대상이 잘나와있고 저희 애들 교육용으로도 보여주고있어요'],
#        dtype='<U48'),
#  array(['국제시장', '10', '너무나 감동적인 어른들의 이야기'], dtype='<U17'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10', '눈 팅팅 부음 내일 학교 어케 가지'], dtype='<U19'),
#  array(['국제시장', '10', '수십번은 본거 같습니다. 그런데 항상 눈물 범벅이 되네요ㅠㅠ'], dtype='<U33'),
#  array(['국제시장', '10', 'ㅠ ㅇ ㅠ ㅇ ㅠ ㅇ ㅜ ㅇ ㅠ ㅇ ㅜ'], dtype='<U21'),
#  array(['국제시장', '10',
#         '마지막 주인공이 자신의 아버지에게 이정도면 잘했지요? 하는 장면이 제일 슬펐어요 삶을 살아감에 있어, 마무리하는 시기에 저도 제 스스로 열심히 살았다 자신했음좋겠네요 윗세대분들의 희생으로 일궈진 ㅠ 눈물겨운 스토리 넘 잘봤습니다'],
#        dtype='<U127'),
#  array(['국제시장', '1',
#         '전형적인 한국 B급 신파극.이게 명작이라고 하는 사람들은 객관적으로자기 자신의 수준을 되돌아보길 바람'],
#        dtype='<U56'),
#  array(['국제시장', '10',
#         '전쟁을 겪거나 전쟁후의 삶을 살아내신 할아버지 할머니 모든 분들의 고단한 역사의 한페이지가 고스란히 영화에 담겼어요. 꼬맹이때 이산가족 테레비 봤던 기억이 나는군요...'],
#        dtype='<U94'),
#  array(['국제시장', '10', '원래 영화보면 잘 안우는데 이산가족 상봉부터 참을 수 없는 울음이 터져나옴'],
#        dtype='<U41'),
#  array(['국제시장', '10',
#         '단연 최고의 영화라 할 수 있는 영화입니다 평소 황정민 배우님 좋아해서 이번 영화도 추천받아 봤는데 진짜 별 생각 없이 봤다 폭풍 눈물 흘렸습니다'],
#        dtype='<U81'),
#  array(['국제시장', '8',
#         '국뽕보수영화라고 욕하는 사람도 있는데. 전혀 동의못함 가족을 위해 열심히 살아가는 남자의 이야기는 눈물을 흘리기에 충분했다'],
#        dtype='<U68'),
#  array(['국제시장', '10', '고생했습니다....'], dtype='<U10'),
#  array(['국제시장', '10', '말이 필요없는 명작 이런영화가 찐 천만영화지'], dtype='<U24'),
#  array(['국제시장', '10', '눈물 흘렸어요ㅠㅠ 감동깊은 영화!!!'], dtype='<U20'),
#  array(['국제시장', '8', '세대를 아우르는 시대의 파노라마'], dtype='<U17'),
#  array(['국제시장', '6', '상업성에 치우친 신파극 작품성은 그닥'], dtype='<U20'),
#  array(['국제시장', '10', '30분 울었어요 최고로 기억남는영화 최고!'], dtype='<U23'),
#  array(['국제시장', '10', '그냥 봐야한다.친구 추천으로 봤는데 넷플릭x 에서보고 내 최고의 영화가 된듯 합니다'],
#        dtype='<U46'),
#  array(['국제시장', '10', '모든 장면에서 눈물 쏟던 영화'], dtype='<U16'),
#  array(['국제시장', '3', '애국과 민족 버전의 2007년 해운대'], dtype='<U20'),
#  array(['국제시장', '2',
#         '네이버 평점은 영화적 완성도와 상관 없는건가.완성도를 평가하는 평점이 따로 있으면 좋겠다.이런 영화가 9점대라는건 말이 안된다.'],
#        dtype='<U71'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10', '힘든 시대를 살아오신 아버지의 이야기...뭉클하네요'], dtype='<U28'),
#  array(['국제시장', '10',
#         '주인공은 40년대생이지만 50년대생까지는 고생 많이 하셨지. 60년대에 경공업, 70년대에 중화학공업을 육성하는데 값싼 노동력은 필수였고 파독노동자, 월남파병까지 다 저 세대들임'],
#        dtype='<U99'),
#  array(['국제시장', '10', '얼마나 개고생 했겠냐 ㄷㄷ우리가 관심없던 시절의 윗윗세대들의이야기'], dtype='<U36'),
#  array(['국제시장', '10', '정말 힘들었는게 느껴진다기댈곳 하나없이...'], dtype='<U24'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10', '아버지시대 어른분들이 그시대 계셨기에 지금의 우리가 있는거 같습니다.'],
#        dtype='<U38'),
#  array(['국제시장', '1', 'cj야 이걸 영화라고 만들었냐'], dtype='<U16'),
#  array(['국제시장', '10', '뒤늦게 보고 감동받아 별점 찍으러옵니다.'], dtype='<U22'),
#  array(['국제시장', '10', '뒤늦게 보고 감동받아 별점 찍으러옵니다.'], dtype='<U22'),
#  array(['국제시장', '1', '순 포레스트 검프인줄 ;양심 좀 챙기세요 감독님아'], dtype='<U27'),
#  array(['국제시장', '10', '달리 1500만 관객이 아니다. 최고!!'], dtype='<U22'),
#  array(['국제시장', '9',
#         '나라의 꿀맛만 빨아본 인생선배인척 하는 40-50대 꼰대들은 절대 이해 못하는 진짜 인생선배들의 이야기. 어르신들, 20대인 저는 당신들을 존경합니다. 고생많으셨습니다.'],
#        dtype='<U94'),
#  array(['국제시장', '10', '슬퍼요~ 특히 방송국에서 여동생이랑 통화 하는게 너무 슬픔입니다'], dtype='<U35'),
#  array(['국제시장', '8',
#         '노인분장만 잘했더라면 좋았을텐데 아쉽다. 우리 이웃의 삶이 내 피속에도 묻어있나보다 남일같지 않은 우리역사.'],
#        dtype='<U60'),
#  array(['국제시장', '8',
#         '노인분장이 너무 어색해서 영화에 몰입을 방해했지만, 영화 자체는 잘 만들었고, 재미있게 잘 봤습니다. 우리 어르신들의 고생에 다시한번 감사합니다.'],
#        dtype='<U81'),
#  array(['국제시장', '10', '재미있다영화보면서 울고 웃을수 있는 최고의 영화다'], dtype='<U27'),
#  array(['국제시장', '10',
#         '영화관 포함 3번정도 본것 같네요.내용을 알고봐도 웃고 눈물 나는 작품입니다.대한민국의 모든 가장들, 화이팅입니다!'],
#        dtype='<U64'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '8', '감동이네요...ㅠ 잘봤어요'], dtype='<U14'),
#  array(['국제시장', '10', '중국이 너무 싫어요 공산당이 싫어요'], dtype='<U19'),
#  array(['국제시장', '10', '볼때마다 얼굴이 눈물로 범벅되는 영화'], dtype='<U20'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '9',
#         '평론가의 평점이 높은 난해한 영화보다 훨씬 낫다. 적어도 내게는 그렇다. 재미와 감동 2마리 토끼를 다 잡은 수작.'],
#        dtype='<U64'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '9', ''], dtype='<U4'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '7',
#         '14.12.25.한국판 포레스트 검프. 그를 통해 한국이 얼마나 힘들게 버텨왔는지가 보인다.다만, 필요치 않다 해도 과한 신파에 조금은 언짢았을뿐.나로서는 이해하기 힘든 감정이다.'],
#        dtype='<U100'),
#  array(['국제시장', '10', '이 영화는 나이먹을때마다 보면 더슬픔..마지막 황정민이 울때 북받침'],
#        dtype='<U37'),
#  array(['국제시장', '8',
#         '억즙시장이라고 까는 사람도 있지만 난 그냥 저런 사람이 정말 있었다는 사실은 부인할수 없기에 괜찮게 봤다.'],
#        dtype='<U59'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10', '다시 봐도 감동이 그대로네요한참을 웃다가 울다가'], dtype='<U26'),
#  array(['국제시장', '10',
#         '감동적인 장면이 이주 많다한국의 현대사를 유쾌하고 빠르게 그리고 그걸 겼은 우리 할아버지들의 이야기다그들이 그렇게 꽉막힌 건 열심히 살며 다쳤던 아픈 상처 때문이겠지 감사하다 그들이 없었다면 오늘의 우리도 없었겠지우리나라는 소중한 가족을 지키려는 사람들이 만든 소중하고 자랑스런 역사가 있다.'],
#        dtype='<U163'),
#  array(['국제시장', '10',
#         '내가 누리는 이 안락함이 내가 잘나서 누리고 있는게 아니라는 생각이 드네요우리가 꼰대라 칭하는? 우리네 부모님들 덕분 노인분장이 다소 어색했지만 스토리가 참 탄탄해서 감동이었습니다감사합니다나도 내 자식들을 위해 조금은 나은 세상을 만들도록 노력할게요'],
#        dtype='<U139'),
#  array(['국제시장', '10', '이분들의 노고가 없었다면 우리세대들 편하게 못살았을거다'], dtype='<U30'),
#  array(['국제시장', '10', '너무 감동적이라서 여러번 보게 되네요. 황정민 연기가 너무 슬퍼요ㅠㅠ'],
#        dtype='<U38'),
#  array(['국제시장', '10',
#         '정말 존경 받아야 하고 나라를 위해 헌신 하신건 이 세대 분들이지 지금의 내로남불 무능 쓰레기 끝판왕 586 똥물새끼들이 아니라'],
#        dtype='<U71'),
#  array(['국제시장', '10', '6번이나 보았지만 볼 때마다 감동 먹고 울고 있습니다ㅠㅜ!!!'], dtype='<U34'),
#  array(['국제시장', '8', '영화에 대해 잘 모르는 사람이 단순 재미도만으로 주는 평점입니다'], dtype='<U35'),
#  array(['국제시장', '10', '다시봐도 감동적인 영화'], dtype='<U12'),
#  array(['국제시장', '1', '뻔한스토리에 뻔한결말'], dtype='<U11'),
#  array(['국제시장', '1', '뻔한스토리에 뻔한결말'], dtype='<U11'),
#  array(['국제시장', '6', ''], dtype='<U4'),
#  array(['국제시장', '6', '중반부까지는 재밌고 한국의 포레스트검프라고 할만 했는데 후반부 연출이 작위적인게 아쉽다'],
#        dtype='<U48'),
#  array(['국제시장', '9',
#         '영화 국제시장은 차용중이다. 현 세대들에게. 이전 세대에게 갚아야할 빚이 있음을 이야기 한다.영화 국제시장은 위로이다. 이전 세대들에게. 6.25전쟁부터 민주화운동까지 목숨이 여러개가 필요했던 시대에 잘 버텨주었다는 위로이다.'],
#        dtype='<U126'),
#  array(['국제시장', '10', '지금의 대한민국을 만든 사람들의 이야기 잊지 않겠습니다'], dtype='<U30'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10',
#         '연기파 배우들의 활약과 중간 중간 튀어나오는 코믹함, 그 시대의 향수를 불러일으키는 연출과 마지막 황정민 배우님의 열연까지 뭉클함을 안겨주는 영화. 많은 생각이 드는 영화입니다. 숨어있는 역사적 게스트들 또한 포인트..!'],
#        dtype='<U123'),
#  array(['국제시장', '5',
#         '우리나라 정서로 가능한 모든 신파를 짬뽕시킨영화ㅋㅋ 그냥 오락영화로 생각하고 보면 킬링타임으론 괜춚'],
#        dtype='<U55'),
#  array(['국제시장', '10',
#         '할아버지 할머니 세대들이 이 나라를 어찌 만들어왔는지 보인다 광부 간호사 장면은 눈물이 앞을 가린다 난 이 나라를 우리 윗세대들이 살기 힘든 나라로 만들었다고 생각했지만 생각이 고쳐진다 저때는 최소한 갈등 분열은 없었지...'],
#        dtype='<U125'),
#  array(['국제시장', '10',
#         '어머니 아버지가 최선이 아니고 최고를 다하셨기때문에 행동한 가정들이 줄줄이 탄생하게 되었어요. 그 생명의 무계를 짊어진 황정민 아버지가 서럽게 우는장면에 저희 아버지를 그리는 모습입니다 그데로 동화가 되었어요 . 백점만점에 백십점'],
#        dtype='<U128'),
#  array(['국제시장', '10', '너무나도 완벽한 영화. 흠 잡을때가 없는 우리나라 최고의 영화.'], dtype='<U35'),
#  array(['국제시장', '10',
#         '황정민이라는 명배우가 주연을 맡아서감동이 더 진하게 온것같음지금시대에 태어나 살아가는 있는것에 축복과감사함을 느끼게 하네요'],
#        dtype='<U68'),
#  array(['국제시장', '10',
#         '황정민이라는 명배우가 주연을 맡아서감동이 더 진하게 온것같음지금시대에 태어나 살아가는 있는것에 축복과감사함을 느끼게 하네요'],
#        dtype='<U68'),
#  array(['국제시장', '9', '아버지의 소중함을 느끼게해주는 좋은 영화'], dtype='<U22'),
#  array(['국제시장', '10',
#         '감동적인 영화다. 우리 윗세대들 덕분에 나라가 이렇게 잘살게 된거다. 후대는 감사하게 생각해야 한다. 평론가들 죄다 평이 왜저러냐? 무식한 것들. 아버지가 일궈논 나라를 저런 싸가지 없는 후대가 흥청망청 다 말아먹고 있으니 땅을 치고 통탈할 일이다.'],
#        dtype='<U139'),
#  array(['국제시장', '10', '역시 미국만세!!! ㅠ 자유 우파 만세!!!미국 대통령님 도와주세요!!'],
#        dtype='<U39'),
#  array(['국제시장', '10', '그냥 미친듯이 눈물이 납니다'], dtype='<U15'),
#  array(['국제시장', '6', '걍 신파 그이상 그이하도 아닌'], dtype='<U16'),
#  array(['국제시장', '10',
#         '10대에 본 영화중 가장 여운이 진했습니다. 단순한 가족영화가 아닌 깊은 감동과 아픈 역사를 담은 최고의 가족 영화라고 생각합니다. 20대가 된 지금도 여전히 국제시장을 볼 때마다 감동입니다.'],
#        dtype='<U107'),
#  array(['국제시장', '10',
#         '우리나라에 그런 분들이 있기에 우리가 이 나라에 잘 살고 있다 그분들도 지금은 나이가 드셨지만 그 당시에는 정말 어리고 맘 여린 상태셨을텐데 진짜 감사합니다 개인적으로 잃어버린 동생을 이산가족 찾기에서 찾는게 가장 감동적이었어요'],
#        dtype='<U127'),
#  array(['국제시장', '10', '짱깨는 옛날이나 지금이나 도움이 안되네'], dtype='<U21'),
#  array(['국제시장', '10', '좋아요 마음을 울립니다'], dtype='<U12'),
#  array(['국제시장', '10',
#         '국제시장을 조금 늦게 지금 보았습니다. 우리나라에서 이렇게 좋은 영화가 나와서 볼 수 있음에 감사합니다. 우리나라 한국전쟁 전후 사람들의 생활상, 서독에 광부, 간호사로 갔던 일, 베트남 전쟁, 그리고 현대까지, 역사적으로도 많은 공부가 되어서, 그리고 가족이란 어떤 것인지 그 의미를 다시 되새겨 볼 수 있어서 너무 좋았고 뭉클했습니다.또 보고 싶어지네요^^~'],
#        dtype='<U202'),
#  array(['국제시장', '10', ''], dtype='<U4'),
#  array(['국제시장', '10', '100번 보면 100번 다 우는 영화 ㅜㅜ'], dtype='<U23'),
#  array(['국제시장', '10', '감동적입니다 꼭보세요'], dtype='<U11'),
#  array(['국제시장', '10', '이영화가진짜아카데미상감이지~~'], dtype='<U16'),
#  array(['국제시장', '10',
#         '이걸 왜 이제봤을까….우리 할아버지할머니 세대분들이 얼마나 치열하게 살아오셨는지…. 정말 감사합니다.'],
#        dtype='<U56'),
#  array(['국제시장', '1', '이것 저것 다 때려넣은 짬뽕같은 영화'], dtype='<U20'),
#  array(['어벤져스: 엔드게임', '10', '말이 필요 없음... 굳이 말하자면 두 글자로 표현 가능함.완벽'],
#        dtype='<U35'),
#  array(['어벤져스: 엔드게임', '10', '액션,스토리,배우,전율,감동을 모두 가진 최고의영화'], dtype='<U28'),
#  array(['어벤져스: 엔드게임', '10', '내가 영화중 최고의 영화'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10',
#         '할리우드가 보여줄 수 있는 기술의 정점 팝콘무비의 정수 그동안 마블을 사랑했던 모든 이에 대한 헌정시'],
#        dtype='<U56'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '인생 통틀어 최고의 영화'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10', '와 평점 봐...와우 대박!'], dtype='<U15'),
#  array(['어벤져스: 엔드게임', '10',
#         '엔드게임은 진짜 볼 때마다 새로움.. ㅠㅠㅠ 엔딩 크레딧에서 원년멤버들 마지막에 나오면서 근본 ost 나올 때 전율 돋음'],
#        dtype='<U67'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '3000만큼 사랑해 로다주'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '개재밌음 걍 소름 돋음 ~~'], dtype='<U15'),
#  array(['어벤져스: 엔드게임', '10', '멋짐 멋짐 멋짐 멋짐 !!'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10', '이게 영화지 ㄹㅇ...'], dtype='<U12'),
#  array(['어벤져스: 엔드게임', '10', '완벽 그 자체….. 더 할말이 없다'], dtype='<U19'),
#  array(['어벤져스: 엔드게임', '10', '역대 최고 마블영화!!!'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10',
#         '닥터가 토니 보면서 손가락으로 더 원(1/1400만의 유일한 방법) 할때 토니를 쳐다보는 닥터의 모습 그걸 받아들이는 토니의 모습..'],
#        dtype='<U74'),
#  array(['어벤져스: 엔드게임', '10', '무슨 말이 더 필요한가.. ㅠㅠ 어벤져스 포에버'], dtype='<U26'),
#  array(['어벤져스: 엔드게임', '10', '하나부터 열까지 거를게 없다'], dtype='<U15'),
#  array(['어벤져스: 엔드게임', '10', '내 인생 최고의 영화이 시대에 태어났음이 감사하다'], dtype='<U27'),
#  array(['어벤져스: 엔드게임', '10', '모든게 완벽한 영화다 내 인생 최고의 영화'], dtype='<U23'),
#  array(['어벤져스: 엔드게임', '10', '다시봐도 명작 ㅜㅜ보고싶다 언맨이'], dtype='<U18'),
#  array(['어벤져스: 엔드게임', '10', '어벤져스 시대에 태어난게 그저 감사할뿐... 세기의 명작'],
#        dtype='<U31'),
#  array(['어벤져스: 엔드게임', '10', '저는 마블을 3000보다 더 사랑합니다. 캡틴바이바이ㅠ'], dtype='<U30'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '어벤져스는 모든게 완벽하다'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '9', '어벤저스 시리즈 팬으로서가장 깔끔하고 좋은 마무리가 아니었나싶다ㅎ'],
#        dtype='<U36'),
#  array(['어벤져스: 엔드게임', '10', "I'm Ironman."], dtype='<U12'),
#  array(['어벤져스: 엔드게임', '10',
#         '2021년의 마지막날 다시 추억을 곱씹어 보았습니다자신밖에 모르고 언제나 자신이 먼저였던 토니는 결국 자신을 희생해서 많은 이들을 구했습니다어느 누군가에는 한낱 히어로 영화로 치부될지도 모르겠지만 저에게는 따뜻한 심장을 가지고 있던 당신이 많이 생각나는 영화가 될것 같네요 2022년에는 저도 당신처럼 열정적이고 유쾌하고 많은 이들을 배려할줄 아는 사람으로 거듭나길 바라면서 이만 줄입니다 3000만큼 아니 30000만큼 고마웠어요 어벤져스와 토니스타크.'],
#        dtype='<U254'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10',
#         '3시간이 전혀지루하지않은... 친구들이 왜 히어로물보냐고할애부터 엑스맨부터..진짜... 3천만큼 사랑합니다. 토니랑 스칼렛요한슨 비전 모두 다 보고싶다 ㅠ.ㅠ 마블 최고!!!'],
#        dtype='<U97'),
#  array(['어벤져스: 엔드게임', '10', '진짜 사랑해 어벤져스ㅜㅜㅜ'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10', '나의 영원한 인생 영화다!!'], dtype='<U15'),
#  array(['어벤져스: 엔드게임', '10', '그냥 최고였던거 같음..'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10', '그냥 최고였던거 같음..'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', 'I am iron man.'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10', '또 보고싶다 넘 감동 ㅠㅠ'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10',
#         '내 인생영화가 될 만큼 너무 감동적이고 스릴있습니다!마블 감사합니다!!꼭 보시길 추천합니다'], dtype='<U50'),
#  array(['어벤져스: 엔드게임', '10', '아이언맨 3000만큼사랑하고 고생했어요고마워요 토니스타크역 로버트다우니주니어'],
#        dtype='<U42'),
#  array(['어벤져스: 엔드게임', '10', '아이언맨 3000만큼사랑하고 고생했어요고마워요 토니스타크역 로버트다우니주니어'],
#        dtype='<U42'),
#  array(['어벤져스: 엔드게임', '10', 'OO ㅠㅠ 너무 감동적이야 ㅠㅠㅠ'], dtype='<U18'),
#  array(['어벤져스: 엔드게임', '10',
#         '대의와 명분을 갖추고 옳은일 하려는 애를 덩치가 크고 피부가 보라색이란 이유로 일진들이 다구리 치는 영화...'],
#        dtype='<U61'),
#  array(['어벤져스: 엔드게임', '10', '재밌음재밌음 ㄹㅇ 개꿀'], dtype='<U12'),
#  array(['어벤져스: 엔드게임', '10', '재밌음재밌음 ㄹㅇ 개꿀'], dtype='<U12'),
#  array(['어벤져스: 엔드게임', '10', '슬픈 장면 때문이 아닌 전율 만으로도 울음을 터트리게 하는 영화'],
#        dtype='<U35'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '완전 재있음 어린이들에게 추천!'], dtype='<U17'),
#  array(['어벤져스: 엔드게임', '10',
#         '2007-8년부터 쌓아온 한 페이즈의 끝을 너무도 잘 맺은, MCU 팬에게 완벽한 영화. 이 영화를 보면서 (울면서) 다음 페이즈부터는 어떻게 영화를 볼지 오히려 걱정됐고,이 영화를 본 이후로 MCU에서 아이언맨이 언급될 때마다 울음이 나올 것만 같다.'],
#        dtype='<U141'),
#  array(['어벤져스: 엔드게임', '10', '와칸다 포에버부터 어벤저스 어셈블까지'], dtype='<U20'),
#  array(['어벤져스: 엔드게임', '10', '와칸다 포에버부터 어벤저스 어셈블까지'], dtype='<U20'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '어벤져스 팬으로 제일 재미있게 봤던 영화'], dtype='<U22'),
#  array(['어벤져스: 엔드게임', '10', '어벤져스 팬으로 제일 재미있게 봤던 영화'], dtype='<U22'),
#  array(['어벤져스: 엔드게임', '10', '아...ㅜㅜ아이언맨'], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '말이 필요없음....'], dtype='<U11'),
#  array(['어벤져스: 엔드게임', '10',
#         '스파이더맨 보고 와서 생각나서 다시옴.. 어셈블 보면 아직도 눈물남 .. 처음으로 별점쓰고 처음으로 10점 주고 간다..'],
#        dtype='<U67'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10',
#         '말뭐말뭐.. 사실 인피니티워 때문에 기대도 엄청 컸는데도 그 기대를 져버리지않는 마블... 정말 이런 영화를 어떻게 만든걸까 명작이다.'],
#        dtype='<U75'),
#  array(['어벤져스: 엔드게임', '10', '아이언맨1 부터 본사람들은 재미없을수 없는 영화.'], dtype='<U27'),
#  array(['어벤져스: 엔드게임', '10', '아이언맨1 부터 본사람들은 재미없을수 없는 영화.'], dtype='<U27'),
#  array(['어벤져스: 엔드게임', '8', '팬들과 함께 보는 발자취'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10', '영상이 3시간이던 4시간이던 무 편집 영상을 보고 싶음 특히 후반 전투 씬...'],
#        dtype='<U44'),
#  array(['어벤져스: 엔드게임', '10', '말해 뭐해... 최고다'], dtype='<U12'),
#  array(['어벤져스: 엔드게임', '7', '인피니티 워의 무지막지한 파괴력에 비해 위엄부족한 종결.'], dtype='<U31'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '진짜 내인생에 이런 영화를 볼수있는게 행복하다'], dtype='<U25'),
#  array(['어벤져스: 엔드게임', '10', '10년의 기나긴 여정.엔드게임은 그 서사의 완벽한 마무리였다.'],
#        dtype='<U34'),
#  array(['어벤져스: 엔드게임', '10', '감탄사 연습하기 딱 좋은 영화'], dtype='<U16'),
#  array(['어벤져스: 엔드게임', '10',
#         '마블 나의 청소년기 10년을 빛나게 채워줘서 고마워...? 앞으로도 많이 그리울거야ㅠ'], dtype='<U47'),
#  array(['어벤져스: 엔드게임', '10', '3000만큼 사랑해!!'], dtype='<U12'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '아직도 안본사람? 꼭 보세요.ㄹㅇ 안보면 후회합니다'], dtype='<U28'),
#  array(['어벤져스: 엔드게임', '10', '한마디로대박이라할수있습니다'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10', '완전따따봉 최고옹 !!!'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10', '완전따따봉 최고옹 !!!'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10', '그냥 완벽한 영화다 평점 10점임 무조건'], dtype='<U22'),
#  array(['어벤져스: 엔드게임', '10', '너무나도재미있어서정말재밌다'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10', '너무나도재미있어서정말재밌다'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '8', '다된 밥에 캡틴 마블뿌리기'], dtype='<U14'),
#  array(['어벤져스: 엔드게임', '10', '마지막 장면 진짜 감동...'], dtype='<U15'),
#  array(['어벤져스: 엔드게임', '10',
#         '이 영화는 남녀노소 마블 좋아하면 다 좋아할 것 같다.진짜 아바타보다 인생영화다!'], dtype='<U45'),
#  array(['어벤져스: 엔드게임', '10', '오랜만에 다시 봤는데도 진짜 찐감동..'], dtype='<U21'),
#  array(['어벤져스: 엔드게임', '8',
#         '시간속에 영원한 것은 없다... 영웅들도 먼지처럼 사라진다...시간을 지배하는 자가 되고싶다.,'],
#        dtype='<U53'),
#  array(['어벤져스: 엔드게임', '10', '내 마지막 마블 영화는 영원히 엔드게임일것'], dtype='<U23'),
#  array(['어벤져스: 엔드게임', '10',
#         '아이엠 아이언맨... 마블 역대 영화 중 최고의 명대사!!!우리는 당신을 영원히 잊지 않습니다.'],
#        dtype='<U53'),
#  array(['어벤져스: 엔드게임', '10',
#         '명대사,명장면이 엄청 많고 감동 및 개그도 좋았는데……이 영화 이후 마블도 점점 앤드해 가는 느낌적인 느낌은 뭐지?'],
#        dtype='<U64'),
#  array(['어벤져스: 엔드게임', '10', '역사에 남을 명작이었다.'], dtype='<U13'),
#  array(['어벤져스: 엔드게임', '10', '마블 페이즈1~3 작품들 정주행하고보니 대작이다 정말..'],
#        dtype='<U31'),
#  array(['어벤져스: 엔드게임', '10', '다시 보면서도 또 한 번 감동을 받았어요 ㅠㅠ'], dtype='<U25'),
#  array(['어벤져스: 엔드게임', '10',
#         '오늘 오랜만에또봤다 토르어머님 만나는씬에서 가오갤 제이슨 병맛씬 넘어가는구간 너무좋다'], dtype='<U47'),
#  array(['어벤져스: 엔드게임', '10',
#         '오늘 오랜만에또봤다 토르어머님 만나는씬에서 가오갤 제이슨 병맛씬 넘어가는구간 너무좋다'], dtype='<U47'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '진짜 최고,,처음부터 끝까지 울면서 봤다'], dtype='<U22'),
#  array(['어벤져스: 엔드게임', '10', ''], dtype='<U10'),
#  array(['어벤져스: 엔드게임', '10', '최고! 마블최고의 작품'], dtype='<U12'),
#  array(['어벤져스: 엔드게임', '10', '미쳐따리 너무 좋아 열번봐야지'], dtype='<U16'),
#  array(['겨울왕국 2', '10',
#         '겨울왕국2의 스토리가 훨씬 좋았어요^^전 유치원 선생님이예요여자아이들이 겨울왕국이후에 파랑색에 편견이 살짝 줄어서 좋습니다^^ 여자친구들의 옷과 신발에 하늘색과 보라색이 엄청 많아요디즈니가 겨울왕국을 통해 파랑을 선물했다는 글을 봤는데 감사해요^^저도 파랑색 좋아합니다'],
#        dtype='<U150'),
#  array(['겨울왕국 2', '8', ''], dtype='<U6'),
#  array(['겨울왕국 2', '10',
#         '겨울왕국1이 정말 재미있어서 기대를 많이 했습니다. 역시 겨울왕국2도 정말로 재미있었습니다. 스토리도 정말 탄탄하고 또한 연출이나 영상미도 좋았습니다. 그리도 또한 겨울왕국1만큼 OST도 정말로 좋았습니다. 저는 겨울왕국3도 기대해 봅니다^^.'],
#        dtype='<U136'),
#  array(['겨울왕국 2', '10', '지금 봐도 오지는 영화임..정말 엘사는 미모가 레전드고ost는 감동까지... 완벽'],
#        dtype='<U45'),
#  array(['겨울왕국 2', '7',
#         '1편보다 OST가 별로인 것 빼곤 잘 만든 작품입니다. 1편은 영화에 별 관심없는 사람도 흥얼거리게 만들만큼 어디선가 들어본 듯한 친숙한 멜로디가 명작임을 느끼게 해주는데 그런 것이 없어서 많이 아쉽습니다.'],
#        dtype='<U115'),
#  array(['겨울왕국 2', '10',
#         'ost는 정말 말이 안 나오게 멋졌고 엘사의 옷은 정말 예뼜다. 안나가 여왕이 된 것도 정말 기분 좋다'],
#        dtype='<U57'),
#  array(['겨울왕국 2', '10', ''], dtype='<U6'),
#  array(['겨울왕국 2', '10', ''], dtype='<U6'),
#  array(['겨울왕국 2', '10', '행복해지는 영화입니다'], dtype='<U11'),
#  array(['겨울왕국 2', '10',
#         '완전... 완전 입이 딱 벌어지는 스케일! 너무나 아름답고 임팩트있는 애니메이션이었다. 자기가 있어야할 곳, 자연스러운 본연의 모습으로 존재할수 있는 제자리를 찾는 과정도 감동적이고 장면 하나하나가 너무너무 예술적이고 스토리도 잼났다.'],
#        dtype='<U131'),
#  array(['겨울왕국 2', '9', '너무 아름다워요 디즈니 짱'], dtype='<U14'),
#  array(['겨울왕국 2', '10', '너무너무너무재밌당ㅇ'], dtype='<U10'),
#  array(['겨울왕국 2', '6', '렛잇고 렛잇고 렛잇고~'], dtype='<U12'),
#  array(['겨울왕국 2', '10', '노래대박이고 스토리도 대박마지막에 눈물흘림'], dtype='<U23'),
#  array(['겨울왕국 2', '10', '징짜오ㅓㄴ전 개머시서'], dtype='<U11'),
#  array(['겨울왕국 2', '8', '잘 만들었는데, 1편이 너무 전설이라..'], dtype='<U22'),
#  array(['겨울왕국 2', '8',
#         '1보다는 재미없다. 1과 비교해서 재미없다는 거지, 영화 자체는 볼만하다. 그럼에도 8점을 준 이유는 중간중간 나오는 크리스토프 때문이다. 1에서 크리스토프는 고마운 조력자였지만 2에서는 그렇게 꼴 보기 싫다...'],
#        dtype='<U119'),
#  array(['겨울왕국 2', '10', '그래픽이랑 ost 개좋음'], dtype='<U13'),
#  array(['겨울왕국 2', '1', '아우 노잼'], dtype='<U6'),
#  array(['겨울왕국 2', '10', '말해뭐해 역시는 역시지 ㅋㅋ코시국에 집콕하며 보기 딱!'], dtype='<U30'),
#  array(['겨울왕국 2', '6', '1편만 못한 속편'], dtype='<U9'),
#  array(['겨울왕국 2', '9',
#         '기대 안하고 봤는데 너~~무 너무 재밌었어요~ 애정하는 캐릭터들 부모님과 얽힌 신비로운 이야기에 멋진 정령들 모습까지 더해져서요~ 엘사가 물의정령 말 타는 모습은 역대급으로 아름다워요..안나가 마법의 힘 없이도 용기 하나로 어둠 속을 나아가 사람들을 구해내고 여왕이 된 것도 좋았어요~ 음악도 올라프도 스벤도 다 좋았어요 3편도 만듭시당ㅎㅎ'],
#        dtype='<U190'),
#  array(['겨울왕국 2', '10', '기그그오네서긛븨디사속드'], dtype='<U12'),
#  array(['겨울왕국 2', '5', '1이더 재밌다'], dtype='<U7'),
#  array(['겨울왕국 2', '8',
#         '1은 재미없었는데 2는 초반엔 왜 이렇게 생소한 것들 많이 첨가하나 했지만 재밌었음. (안나 남친 노래 부를 때가 제일 지루함) 바다씬부터 웅장해지고 그 웅장함이 뒤에까지 간간히 유지되면서 암튼 쭉 재밌음.'],
#        dtype='<U115'),
#  array(['겨울왕국 2', '9', '감동이 있고 교훈이 있다. 어른이 보기에 더 적합한'], dtype='<U28'),
#  array(['겨울왕국 2', '7',
#         '1편 보고 실망이 커서 그랬는지 이번엔 그래도 재미는 있네요. 여전히 가수의 가창이나 발성은 캐릭터와 전혀 매치 안되고, 애니메이션의 한계는 있지만, 전형적인 해피엔딩과 교훈들은 마음에 쏙 듭니다. 별 반 개 추가할만큼 도마뱀 이뻐요.'],
#        dtype='<U131'),
#  array(['겨울왕국 2', '10', ''], dtype='<U6'),
#  array(['겨울왕국 2', '10', ''], dtype='<U6'),
#  array(['겨울왕국 2', '10', '굿굿 눈물포인트 잇음 ㅜ'], dtype='<U13'),
#  array(['겨울왕국 2', '8',
# ...
#  array(['괴물', '10',
#         '넷플릭스에 본 영화 나와서 오랜만에 다시 봤습니다. 다 좋지만 ost가 제일 좋고 역시 봉준호 감독님 작품답게 명작입니다.'],
#        dtype='<U68'),
#  array(['괴물', '8', '한국 상업영화의 오락성과 예술성이 한 정점으로서 일치하던 지점.'], dtype='<U35'),
#  array(['괴물', '10', '새로운 연출 영상미 대단해요'], dtype='<U15'),
#  array(['괴물', '10', '다시보니 더 명작이에요.그때와 다른 감동이 또 있네요'], dtype='<U29'),
#  array(['괴물', '10', '다시봐도 재밌음 핵꿀잼'], dtype='<U12'),
#  array(['괴물', '10',
#         '거장이 만든 자랑스러운 한국 영화인건 분명. 환경 강대국 사회부조리 가족애 다 소화하려니 난 입맛을 좀 잃는 기분이야'],
#        dtype='<U65'),
#  array(['괴물', '10', '대사 하나하나 뼈가 있는, 숨소리 하나까지 놓칠 수 없는'], dtype='<U31'),
#  array(['괴물', '2', '약간 90년대 같은 대사와 스토리'], dtype='<U18'),
#  array(['괴물', '8', '으엥? 이걸 평점 안남겼었네.. 군제대 하자마자 영화관 가서 본 영화 준호봉 작은 다봤지'],
#        dtype='<U49'),
#  array(['괴물', '10', '영화에 대해 잘 모르는 사람이 단순 재미도만으로 주는 평점입니다'], dtype='<U35'),
#  array(['괴물', '10',
#         "어릴때는 그냥 괴물 나오고 축축하고 끈적한 기분 나쁜 느낌이 계속 보여지고 마지막에는 화살이 멋있다 정도였는데 다시 보니 괴물과 축축하고 끈적한 하수구 풍경보다 더 괴기하고 기분 나쁜 '상황'들이 더 중점적으로 보이는듯. 화살 멋있는건 여전하고.."],
#        dtype='<U138'),
#  array(['괴물', '10', '이건 어케 지금 봐도 재밌냐 15년전 영화인데 현재 나오는 괴물 영화보다 훨씬 잘만듬'],
#        dtype='<U47'),
#  array(['괴물', '10', '봉준호 × 송강호 10점'], dtype='<U13'),
#  array(['괴물', '10',
#         '어쩌면 저 괴물은 지금도 죽지 않고 더 많은 인간을 먹어치우고 번식하여 형성되어지고 있을지도 모른다.'],
#        dtype='<U56'),
#  array(['괴물', '10', '어렸을적 극장에서 봤을땐 단순 스릴러였지만 나이 먹고 보니까 정말 느낌이 다르다.. 초명작'],
#        dtype='<U50'),
#  array(['괴물', '9', '인생영화중 하나임!!!'], dtype='<U12'),
#  array(['괴물', '10',
#         '어쩌면 정말 비교대상이 나오지 않을 것 같은 현대판 한국 괴수물의 최고의 수작. 괴물은 픽션, 사람들 이야기는 논픽션.'],
#        dtype='<U66'),
#  array(['괴물', '10',
#         '배두나님 마지막 불씨로 활쏘는거 존멋 역시 명장면양심의가책1도없이 오염물 방사하는 사람들유가족들울고있는데 셔터누르는 기자들시민들말 귀담아듣지도않고 정신나간사람취급하는 경찰아는형의 배신 믿을사람하나 없는 세상생체실험장앞에서 고기구워먹는 비인간적인 실험자들'],
#        dtype='<U141'),
#  array(['괴물', '10', '15년이 지난 지금도 세련된 서사와 상징'], dtype='<U22'),
#  array(['괴물', '9',
#         "이 영화는 제목을 3번 바꾼다.처음에는 괴수영화였다가 5년이 지난뒤엔 반미 영화로 바뀌었고지금은 '한국 현실'이라는 제목으로 바뀌었다.진짜 괴물은 무엇인가"],
#        dtype='<U86'),
#  array(['괴물', '10', '소름돋고 완변한 대한민국에 몇안되는 영화'], dtype='<U22'),
#  array(['괴물', '9', '재미있기는 한데 군인들이적극 적으로 싸우지 않는 점이 아쉬워요(초딩5학년)'],
#        dtype='<U41'),
#  array(['괴물', '10', '인생 영화????????'], dtype='<U13'),
#  array(['괴물', '5',
#         '무얼 비판하려는 건지도 알았고 이해했는데, 뭐 또 가족에 대한 이야기. 눈 앞에 보이는 괴물이라는 존재보다 인간들끼리 싸우다 개판되면서 희생되다 결국 민간인이 괴생명체를 물리치는 모순이랄까. 결국 국가가 나서서 해결하지 않는다는 점. 다 이해했는데 그냥 내 기준에선 그 정도로 여운은 안 남네. 확실히 국가가 나서서 해결하지 않으니까 진짜 고구마만 먹는 느낌이었음. 그게 비판 요소로 사용하려는 것도 알겠는데 내 기준에선 그 정도의 대작이라고는 안 느껴짐.'],
#        dtype='<U255'),
#  array(['괴물', '9',
#         '20대 처음 봤을때는 괴물과의 사투가 재미있었는데, 나이들어보니 한국 사회의 문제점들을 우회적으로 많이 비판하는 것이 보였다.'],
#        dtype='<U70'),
#  array(['괴물', '10',
#         '초딩때 최소 10번씩은 돌려본 영화. 성인되고 클립으로 다시 보니 초딩땐 느껴보지 못했던 감정들이 새롭게 느껴졌다.'],
#        dtype='<U64'),
#  array(['괴물', '10', '현서를 죽인건 결국 괴물이 아니라 이나라 였고끝까지 싸운건 결국 평범한 시민이였다.'],
#        dtype='<U46'),
#  array(['괴물', '10', '말해 뭐해 다시봐도 재밌고 생각거리만 늘어난다'], dtype='<U25'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', '당시 한국에 이런 영화가 나왔음에 박수를.'], dtype='<U23'),
#  array(['괴물', '10', '와!!!!이런영화는처음!'], dtype='<U13'),
#  array(['괴물', '10', '한강의 괴물, 언젠가 있었을 법한 자연스러움'], dtype='<U24'),
#  array(['괴물', '10',
#         '진짜 난 그냥 그런공포영화인가 했지만 인간에 모순?이라고해야하나..쨋든 그런영화인것같음인간이 한 무책임한행동때문에 누군가가 불행해지고 괴물은 죄도 없는데 변이가되서 미움을받고 결국 마지막에는 죽고 아 ㄹㅇ 마지막에 죽이는장면은 킬포임 개간지'],
#        dtype='<U134'),
#  array(['괴물', '10', '시간이 지나 다시봐도 너무 재밌다'], dtype='<U18'),
#  array(['괴물', '10', '대한민국 최고의 괴물영화!!'], dtype='<U15'),
#  array(['괴물', '10', '누가 괴물인가....'], dtype='<U11'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', '괴물만 있는줄 알았는데 다시보니 사회도 담겨져 있다'], dtype='<U28'),
#  array(['괴물', '8', ''], dtype='<U2'),
#  array(['괴물', '9', '뫼비우스의 띠 같은 모순 덩어리 사회 비판의 풍자 총 집합체 같은 느낌이다.'],
#        dtype='<U42'),
#  array(['괴물', '10', '대한민국 최고의 괴물영화'], dtype='<U13'),
#  array(['괴물', '10',
#         '요즘 시대에 더 잘 맞는 영화이지 싶다 존재하지도 않는 바이러스로 인한 선동과 바이러스가 있길 바라는 무시무시한 생각을 하는 언론과 외신 단 몇 초만 검색해도 위치추적이 가능한 민간기업과 말도 안되는 절차 핑계로 인권 따위는 개나 줘버린 무능한 경찰 검역하라더니 대충 얼버무리는 공무원들의 탁상행정과 의료진의 갑질 요즘 같은 가짜뉴스가 판치고 자신의 이득을 위해서라면 법과 양심을 쉽게 버리는 괴물같은 인간들이 판치는 시대에 지금 이 영화가 개봉된지 15년이나 됐지만 오히려 2021년 현재에 더 와닿는 영화 같다'],
#        dtype='<U287'),
#  array(['괴물', '10', '코로나가 생각나...'], dtype='<U11'),
#  array(['괴물', '8', '씁쓸한 뒷맛이 감도는 창의적인 봉준호식 풍자극.'], dtype='<U26'),
#  array(['괴물', '8',
#         '지금 다시 봐도 독창적 스토리 및 각각의 개성이 확실한 모든 캐릭터, 적절한 시대 반영, 신파가 아닌 한국 정서 표출 등 완벽한 연출. 코미디 장르 맞는데 왜 눈물이 나는지'],
#        dtype='<U96'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '8', '끝에 딸은 죽이지 말지 ㅠㅠ'], dtype='<U15'),
#  array(['괴물', '10', '바이러스 시대를 기가 막히게 표현햇다'], dtype='<U20'),
#  array(['괴물', '10',
#         '14년전에 봤던 영화.우연찮게 EBS에서 다시보게 된 영화.지금 다시 봐도 손색이 없을 정도로 넘 잘 만든 감동 영화..봉준호 감독은 역시 대단한 인물임.'],
#        dtype='<U86'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', '기대 이상은 아니었지만 그래도 재미있게 잘봣습니다 역시 봉준호감독님 대단하시내요'],
#        dtype='<U44'),
#  array(['괴물', '10',
#         '정말 군더더기 없이 완벽하다. 21세기 영화지만, 묘하게 그 이전 세기의 클래식함이 느껴지는 작품.'],
#        dtype='<U55'),
#  array(['괴물', '8',
#         '왜 심형래는 독창적이고 한국적인 이런 괴수영화를 만들지 못했나? 킹콩 고질라만 따라하는 재능없는 신지식인...'],
#        dtype='<U61'),
#  array(['괴물', '9', '그 시절 내가 본것은 괴물이 맞다'], dtype='<U18'),
#  array(['괴물', '8', '코믹부분 너무 어설퍼.. 그리고 마무리도 어설퍼.. 이 부분만 더 잘했으면..'],
#        dtype='<U43'),
#  array(['괴물', '10', '시간이 흘러도 명작은 명작이다. 지금 다시봐도 재밌네.'], dtype='<U30'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', '진짜 띵작중에 띵작.정말 잘 만든 영화'], dtype='<U21'),
#  array(['괴물', '10', '내 인생 최고의 영화.개인적으로 기생충보다도 더 완벽하다.'], dtype='<U32'),
#  array(['괴물', '10', '대단한 명작이다! 한국 사회를 이렇게 정확하게 진단하셨다니!'], dtype='<U33'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10',
#         '이 영화는 단순한 봉테일의 명작 중의 명작이 아니라 세계의 네임드 괴수물의 클리셰를 뒤튼 영화입니다. 대부분의 네임드 괴수물의 주요 장르는 주인공 일행이 도시를 부수도 다니는 거대한 괴수에 맞서 싸우는 장르가 대부분입니다. 하지만 봉준호 감독의 괴물은 그런 클리셰를 따르지 않고 대낮에 괴수가 출연하여 주인공 일행이 사태를 극복해 나가면서 결국 괴물을 만나자 괴물과 부딪치는 등 기존의 괴수물과의 클리셰가 상당히 다릅니다.'],
#        dtype='<U236'),
#  array(['괴물', '10', '괴물은 다른게 아닌 사람이었네요'], dtype='<U17'),
#  array(['괴물', '10', '걍 존잼임ㅋㅋ히히ㅋㅋㅋ'], dtype='<U12'),
#  array(['괴물', '10', '14년이 지난 지금, 괴물은 여전히 살아있네요, 그것도 더 끔찍한 모습으로...'],
#        dtype='<U44'),
#  array(['괴물', '10',
#         '곱씹어봐야 맛을알듯 여러번보니 캐릭터의 메세지가 보여진다 봉감독의 숨박꼭질 찾았다~!라고할수있겠나??난여전히 투비 컨 틴뉴~'],
#        dtype='<U69'),
#  array(['괴물', '1',
#         '봉준호 영화는 보면 볼수록 촌스러워. 담겨있는 메세지가 구닥다리 좌파 냄새남. 살인의 추억 하나 빼고 나머지 영화들은 내 스타일이 영 아님.'],
#        dtype='<U78'),
#  array(['괴물', '10', '다시 봐도 지루하지 않는 영화 7광구는 왜 그랬는지 신기'], dtype='<U31'),
#  array(['괴물', '9', '오히려 기생충보다 이 영화로 아카데미를 쓸었으면 이해가 감..'], dtype='<U34'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', '14년후에 다시보니 더 와닿고 더 느끼는 바가 크다현실감있어서 슬픈'], dtype='<U37'),
#  array(['괴물', '9', '괴물로 우리 사회를 보여준다니.. 완벽한 한국형 괴수영화.'], dtype='<U32'),
#  array(['괴물', '10', '다시보니 처음 볼때보다 더 마음아파요..'], dtype='<U22'),
#  array(['괴물', '1', '바이러스는 어디에도 없다. 예언 영화네'], dtype='<U21'),
#  array(['괴물', '10',
#         '지금 obs다시보기는 씨네마운틴 덕입니다 다시봐도 재미나네요 귀속에 장감독님 은이언니 목소리 들리는건 함정'],
#        dtype='<U59'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', '오래만에 봤는데 이렇게 날카롭게 한국을 해석한줄 모르고 마냥봤었던 것 같다. 감회가 새롭다'],
#        dtype='<U50'),
#  array(['괴물', '10', ''], dtype='<U2'),
#  array(['괴물', '10', '변희봉 괴물한테 날라가는게 너무 슬프고 짠하다 ㅠㅠㅠ'], dtype='<U29'),
#  array(['괴물', '10', '아니 2006년때 천만관객아ㅕㄴ 진짜 진짜 어렵고 그만큼 재밌다는 영황데 아직도 대당하다'],
#        dtype='<U49'),
#  array(['괴물', '9', '영화관에서 처음으로 본, 나에게는 정말 특별한 영화'], dtype='<U28'),
#  array(['괴물', '10', '다시보니 알겠다. 영화가 주는 메시지를.'], dtype='<U22'),
#  array(['괴물', '10', '대한민국 최고의 괴수영화.과연 이런 영화가 또 나올수 있을까?'], dtype='<U34'),
#  array(['괴물', '7', '진짜 괴물은 사람들이다.'], dtype='<U13'),
#  array(['도둑들', '10', '화려한 출연진과 그들의 연기력, 액션, 브금 모두 좋았어요'], dtype='<U32'),
#  array(['도둑들', '10',
#         '영화의 내용, 캐릭터, 영상미, 액션, 유머러스함까지 모두 재밌었던 영화평점 잘 안남기는데 왜 낮은지 모르겠어서 한 표라도 남기고가요'],
#        dtype='<U74'),
#  array(['도둑들', '10', '말이 필요없는영화굿짱짱'], dtype='<U12'),
#  array(['도둑들', '10', '다시봐도 재밌스~~ 속편도나옴 좋겠다'], dtype='<U20'),
#  array(['도둑들', '10', '너무 재미있네요 스토리 연기 출연진 화려함 짱입니다'], dtype='<U28'),
#  array(['도둑들', '10',
#         '여러번을 보아도 질리지 않는 재밌는 영화. 생각보다 평점이 낮아서 조금이라도 높여주고 싶어서 평점 남기고 간다.'],
#        dtype='<U62'),
#  array(['도둑들', '10',
#         '프랑크푸르트 공항까지는 아직 3~4시간 정도 남은 상태..책이나 신문 읽는 것도 질렸고 온몸을 비틀며 자려고 해도 잠은 안 오고..할 수 없이 평소에는 재미없어서 보지 않던 영화 채널을 뒤적이다가 발견하고 별 기대하지 않고 봤던 영화 .결과는 대만족..언제 지루했냐는 듯이 작은 화면 속 장면들에 몰입해서 끝까지 봤고 보고 나니 언제 지루했냐는 듯이 생기가 넘쳤나서 공항 도착을 즐거운 마음으로 기다릴 수 있었다.액션이 좋은 영화라 영화관에서 봤었으면 더 좋았을 것 같지만 지루해 미칠 것 같던 시간을 버틸 수 있었다는 점에서 비행기 조그만 화면에서 본 것도 나쁘지 않았던 것 같다. ** 전지연 등 핫한 젊은 배우들이 있었지만 연륜있는 배우들의 연기에 뭍혔고 존재감은 안 좋은 의미로 영화에 자연스럽게 녺아들지 않고 튀는 식이라 눈에 거슬렸음.'],
#        dtype='<U417'),
#  array(['도둑들', '6', 'The Thieves'], dtype='<U11'),
#  array(['도둑들', '10',
#         '진짜 이건 내인생 최고의 영화 7번을 보고 또 봤는데 너무 재밌음 질리지 않음 이제 대사까지 다 외우는데도 너무 재밌음 전지현 너무 좋고 보면 볼 수록 영화의 매력에 빠져드는… 도둑들2 기대 중이었는데 응… 몇년이 지나도 안나오겠지ㅠㅠ'],
#        dtype='<U131'),
#  array(['도둑들', '10', '지금 봐도 재밌어요. 로프타고 건물 밖에서 싸우는 장면 완전 멋짐'], dtype='<U36'),
#  array(['도둑들', '10', '다시 봐도 정말 재밌음 전지현 예니콜 역할에 넘 찰떡이고'], dtype='<U31'),
#  array(['도둑들', '10', '어른이 되고 나서 보니 더 재밌다'], dtype='<U18'),
#  array(['도둑들', '8', '단순한 이야기와 반대로 캐릭터는 섬세하다'], dtype='<U22'),
#  array(['도둑들', '10', '대 배우들 넘사벽 연기 짱 1000번봐도 잼써용'], dtype='<U26'),
#  array(['도둑들', '10',
#         '뭐 굳이 러브라인을 덜 엮었으면 좋았겠다란 말도 많지만 재밌게 봤음 되도않는 감성팔이 영화보다훨씬 나은 오락 영화임에도 평점이 너무 낮은 듯 인물 하나하나에 다 스토리가 있고 친절하게 다 풀어주기까지 했는데 우리나라에서 얼마나 대단한 영화를 보고 싶은건지'],
#        dtype='<U142'),
#  array(['도둑들', '10',
#         '재밌네요 감동도 있고~~!! 근데 평점이 왜이러지? 가벼운 대화같지만 진심이 있는 영화구만!!'],
#        dtype='<U52'),
#  array(['도둑들', '8', '전지현얼굴하고 몸매가 다했다'], dtype='<U15'),
#  array(['도둑들', '10', '갸꿀잼임 ㄹㅇ 계속봐도꿀잼'], dtype='<U14'),
#  array(['도둑들', '10',
#         '뭐하나 빠뜨린 것 없이 다 갖춘 영화. 영상미도 좋고 배우들 연기력, 캐릭터 다 좋고 스토리도 탄탄하고 재미와 스릴까지, 천만 영화 중에도 손꼽힐 작품인듯.뻔할 것 같아서 여태 안보다가 이제야 봤는데, 좀 놀람.'],
#        dtype='<U118'),
#  array(['도둑들', '10', '볼때마다 재밌음 각캐릭터들 매력적'], dtype='<U18'),
#  array(['도둑들', '7', ''], dtype='<U3'),
#  array(['도둑들', '8',
#         '솔직히 재밌고 우리나라에서 나온 영화치고 스케일도 좋고 연기는 두말할것 없다. 러브라인 쪼끔 줄이고 진짜 쿨하게 만들었으면 더 멋있는 영화였을거 같다.'],
#        dtype='<U84'),
#  array(['도둑들', '7', '김수현이랑 전지현 케미 좋아요 뒤에 많이 나오지 않아서 아쉽 ㅜㅜ'], dtype='<U36'),
#  array(['도둑들', '10', '다시보니 왤케 재밌는지'], dtype='<U12'),
#  array(['도둑들', '9', '다시보니까 스캐일도 크고 다 좋았음. 그런데 배우들이 너무 멋을 부려서 촌스러움.'],
#        dtype='<U45'),
#  array(['도둑들', '10', '첨부터 끝까지 재미있음!'], dtype='<U13'),
#  array(['도둑들', '8',
#         '영화 제대로 이해도 못하고 대충 본 사람들이 낮은 평점 준 듯. 범죄의 재구성, 타짜랑 비교해도 크게 손색이 없을 정도로 잘 만들었다.'],
#        dtype='<U75'),
#  array(['도둑들', '10',
#         '연기들이 일품이라 몰입 깨지는 일이 없어서 좋았다. 스토리는 반전의 반전이 있는 도둑들 이야기에 사랑을 추가한 느낌? 캐릭터들이 하나같이 엄청 매력적임. 중반까진 캐릭터 간 케미가 주는 재미가 있었는데 후반에는 약간 아쉬웠음. 그래도 너무 재밌었다! 아 그림자를 이용한 연출이 개인적으로 맘에 들었음.bb'],
#        dtype='<U170'),
#  array(['도둑들', '10', '박진감 넘치고 시종일관 눈을 뗄수없게 만드는'], dtype='<U24'),
#  array(['도둑들', '10', '몇번을 봐도 지루할 틈 없이 재밌다'], dtype='<U19'),
#  array(['도둑들', '8', '킬링타임으로 볼만하게 재미있게 잘만들었네요'], dtype='<U23'),
#  array(['도둑들', '9', '전지현밖에 기억에 안남는 영화'], dtype='<U16'),
#  array(['도둑들', '10', '믿고보는 최동훈 ㅎㅎ정말 레전드 시간 순삭'], dtype='<U23'),
#  array(['도둑들', '8', '10인의 도둑 1개의 다이아몬드 그들이 움직이기 시작했다'], dtype='<U31'),
#  array(['도둑들', '10', '다시 봐도 시간 가는 줄 모르고 지나가는 영화.'], dtype='<U26'),
#  array(['도둑들', '10', '다 좋은데 한국기동타격대가 홍콩마적단 따위에게 허접하게 당하는건 꼴사납다'],
#        dtype='<U40'),
#  array(['도둑들', '8', '김혜수와 전지현의 매력에 푹~^^'], dtype='<U18'),
#  array(['도둑들', '10',
#         '평점 올리자! 재밌다. 서사 촘촘하고 캐릭터 살아있고 대사 찰지다. 오락영화에서 더이상 뭘 바라는거지?'],
#        dtype='<U57'),
#  array(['도둑들', '10', ''], dtype='<U3'),
#  array(['도둑들', '8',
#         '얽혀있는 실처럼 꼬여있는것 같지만 잡아당겨보니 쉽사리 풀려버리는 느낌. 그렇지만 캐릭터만큼은 역시 최동훈감독이다.'],
#        dtype='<U63'),
#  array(['도둑들', '10', '너무 재밌게 잘봤어요 이걸 왜 이제 봤는지...'], dtype='<U26'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '모두 연기 너무 좋았음. 특히 전지현'], dtype='<U20'),
#  array(['도둑들', '10', '전지현연기가조아요.'], dtype='<U10'),
#  array(['도둑들', '10', '이런 영화가 한번 더 나오면...!!!'], dtype='<U21'),
#  array(['도둑들', '10', '처음 봤을때 재밌게 봤음'], dtype='<U13'),
#  array(['도둑들', '9', '천만관객에는 이유가 있다'], dtype='<U13'),
#  array(['도둑들', '10', ''], dtype='<U3'),
#  array(['도둑들', '10', '보는내내 김혜수 얼굴에 홀려서 봄'], dtype='<U18'),
#  array(['도둑들', '10', '다들 너무 연기를 잘했음'], dtype='<U13'),
#  array(['도둑들', '10', '전지현은 배우로서 못하는게 뭘까 싶음..'], dtype='<U22'),
#  array(['도둑들', '10', '너무 재밌어요 인생영화'], dtype='<U12'),
#  array(['도둑들', '10', ''], dtype='<U3'),
#  array(['도둑들', '10',
#         '아름다운 배우들보는 재미 더하기 반전에 반전을 더하는 스토리는 더재미~~세번째 봤습니다~~도둑들2언제 나오나요 김윤석 전지현 김수현은 꼭 필히 재출연 해주세요~~'],
#        dtype='<U90'),
#  array(['도둑들', '6', '여기저기 유명한 액션 영화들 여러장면 짜깁기한 느낌...'], dtype='<U31'),
#  array(['도둑들', '10',
#         '평점 7.8??? 장난해?? 뭐 또 범죄 미화영화라고 하는거야?? 어이가 없네 진짜ㅡㅡ 그냥 잘 만든 오락영화야 배우들의 연기와 그렇고 참 영화볼줄 모르네.. 영화는 영화일뿐입니다'],
#        dtype='<U100'),
#  array(['도둑들', '10', '평점은 최대 1000자까지'], dtype='<U14'),
#  array(['도둑들', '10', '재밌게 봤는데 생각보다 평점이 꽤 낮아서 10점줌 절대 7점대의 영화는 아닌듯'],
#        dtype='<U43'),
#  array(['도둑들', '1',
#         '대사 하나하나가 아주 드럽게 유치하고, 손발이 오그라들어서 보기 힘들 정도였다.. 그것 뿐이랴? 쓰잘데기 없는 의미없는 장면들 마구 넣어놔서 지루하게 만들고 무슨 대사가 정상적인게 없음.. 왜 이영화가 천만 영화인지 심히 의심이들정도이며, 진짜 너무 실망스럽고 진심 한국 관객들 수준 올려야함'],
#        dtype='<U163'),
#  array(['도둑들', '7', '사랑꾼 하수 도둑들의 우당탕탕 대작전'], dtype='<U20'),
#  array(['도둑들', '10', '완벽하다… 너무 재밌음'], dtype='<U12'),
#  array(['도둑들', '10', '개재밋는데 평점 와이라노'], dtype='<U13'),
#  array(['도둑들', '10', ''], dtype='<U3'),
#  array(['도둑들', '10', '굿굿굿굿드굿굿굿굿드'], dtype='<U10'),
#  array(['도둑들', '10', '재밌는대 평점 왜이래 뭐가문제?'], dtype='<U17'),
#  array(['도둑들', '10',
#         '한국에 이정도로 완성도 높고 스케일 큰 블록버스터 액션 영화가 다시 나올거 같지 않다. 평점 낮게준 찌질이들은 일본 야동이 자기 취향인듯'],
#        dtype='<U76'),
#  array(['도둑들', '10', '? 재밌는데 평점 이따구...ㅋㅋ'], dtype='<U18'),
#  array(['도둑들', '1',
#         '이제평점달지만 정말 신기하네... 이런 배우빨 쓰래기영화가 어떻게1000만관객을 돌파하지? 난 보다가껏는데...이런 냄새나는영화말고 몸다치고 훈련열심히해가면서 찍은영화가 더재미없으면 뭐가되나... 이때당시는 차라리 이거개봉할시간에 월드인베이전같은거라도 더개봉해라 제발...'],
#        dtype='<U152'),
#  array(['도둑들', '9', '도둑이 이렇게 사랑스러웠나..'], dtype='<U16'),
#  array(['도둑들', '8', '킬링타임용으로 좋네용'], dtype='<U11'),
#  array(['도둑들', '10', '너무 재밌는데요 생각보다 평점 되게 낮네요'], dtype='<U23'),
#  array(['도둑들', '10', '10년만에 또 봐도 재밌네요~'], dtype='<U16'),
#  array(['도둑들', '8', '지금 보니까 라인업 진짜 지리네 ㅋㅋㅋ'], dtype='<U21'),
#  array(['도둑들', '9', '시간이 지나고 다시 봐도 재미있음'], dtype='<U18'),
#  array(['도둑들', '2', '이게 천만이라니....'], dtype='<U12'),
#  array(['도둑들', '10', '너무재밌는데요 진작볼껄~'], dtype='<U13'),
#  array(['도둑들', '8', '돌고 도는 뒤통수때리기. 충분히 오락영화로서 즐길 수 있는 영화.'], dtype='<U36'),
#  array(['도둑들', '10',
#         '전지현이 김혜수한테 어마어마한 OO 이라고 하는소리 오랜만에 들으려고 다시 봤닼ㅋㅋㅋ 다시봐도 쫄깃하네.. 전지현 꿈사고파는 연출 해피엔딩 문신 연출 등 오랜만에 봐도 야무지다ㅋㅋㅋ 거를 타선이 없는 주연 캐스팅..ㅎㅎ'],
#        dtype='<U122'),
#  array(['도둑들', '10', '다른건 모르겠고 연기자들 연기력이 다'], dtype='<U20'),
#  array(['도둑들', '8', '참 잘 만든 영화티비에서 몇 번을 재방해도 2년에 한 번은 다시보게되는 영화'],
#        dtype='<U42'),
#  array(['도둑들', '10', '되게 재밌게 봤음. 7점대 영화는 절대 아닌 듯'], dtype='<U26'),
#  array(['도둑들', '7',
#         '빈약한 스토리 전개 호화출연진 만으로 유명해진 영화(당연히 연기력은 좋음) 시간이 흐를수록 평가는 떨어질듯'],
#        dtype='<U59'),
#  array(['도둑들', '10', 'ㅆㅅㅌㅊ ㅋㅋ 존나재밌었음 배우들도 다 ㅆㅅㅌㅊ'], dtype='<U26'),
#  array(['도둑들', '5', '능청스럽고 색기넘치며 사악하기까지 한 애니콜. 그 외는 별로..'], dtype='<U35'),
#  array(['도둑들', '10', '굳 너무 재밌었음 계속 보게된다'], dtype='<U17'),
#  array(['도둑들', '10',
#         '끝까지 완벽했던 영화, 최고의 배우들이 각각의 개성을 잘 살려냈고, 10년전 영화인데도 배우들은 그 모습 그대로네요^^'],
#        dtype='<U66'),
#  array(['도둑들', '10', '오랜만에 봐도 존잼 김수현 진짜 존잘'], dtype='<U20'),
#  array(['도둑들', '10', '짱!!!너무 재밌어요!!!!'], dtype='<U15'),
#  array(['도둑들', '10', '그냥 말이 필요없다 개재밌고 요즘 나오는 뻔한 영화랑은 다르다'], dtype='<U34'),
#  array(['도둑들', '10',
#         '김윤석 너무 멋있고 김혜수 너무 예쁘고,, 사랑에 빠진 남자들 보는 맛에 봤네요 김윤석과 김수현 영화에서 너무 멋있게 나왔어요'],
#        dtype='<U70'),
#  array(['도둑들', '10',
#         '왜케 평점이.. 과소평가 된 듯??속고 속이는 환경에서 사람믿는게 더 어렵고 그만큼 더 값지다는걸 담백하게 나타낸듯웨이홍 캐릭이 너무 깨긴했는뎈ㅋㅋㅋ 스토리는 너무 재밌었음'],
#        dtype='<U96'),
#  array(['도둑들', '9', '정말 재미있게 봤던 영화 캐릭터들도 다 매력있고 지루하지 않음 킬링 타임으로 최고'],
#        dtype='<U45'),
#  array(['도둑들', '8', '생각보다 재밌었음. 한국 배우 중 중국어 어찌 저리 잘함?'], dtype='<U32'),
#  array(['도둑들', '10', '존잼인데 오ㅐ?재미없대!'], dtype='<U13'),
#  ...]

# %%
data_df
# Out:
#        name num                                             review
# 0        명량  10                                   역대 대명작이라 자부합니다^^
# 1        명량  10  진짜 이건 우리나라 영화계에 한 획을 그을 정도에 명작입니다 우리가 역사를 배워야 ...
# 2        명량   3                              국뽕 범벅, 거품, 스크린독점 관객동원
# 3        명량  10  초등 고학년 아들과 진도에 다녀온후 같이 봣는데 정말 감사하고 감동이며 죄송스러운 ...
# 4        명량  10  깊게 숨을 들이쉬고 후하고 내뱉은 뒤, 이 영화를 보아라. 다보고 나서 이틀 뒤에 ...
# ...     ...  ..                                                ...
# 9995  블랙 팬서  10
# 9996  블랙 팬서  10                            와칸다의 왕, 그의 죽음은 끝이 아니길..
# 9997  블랙 팬서  10                      와칸다 포에버!! 당신이 떠났어도 왕국을 지키겠습니다
# 9998  블랙 팬서  10  처음 볼 때는 그저 재미있는 영화라고 생각을 하였습니다. 그런데 암 투병 중에 촬영...
# 9999  블랙 팬서  10                                R.I.P 채드윅. 영원한 블랙팬서
#
# [10000 rows x 3 columns]

# %%
data_df.to_excel("영화목록3.xlsx",engine="openpyxl") #나중에 누가 받을때 오류나면 아마 uft-8 cp949 관련 문제일겨

# %%
######### 노-력 흔적들 #########

# %%
# 영화 이름 10개 이름, 별점, 리뷰내용
b = driver.find_elements(By.CLASS_NAME,"title")
for x in b:
    print(x.text)
# Out:
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 10
# 눈은 즐거웠습니다 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 10
# 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 10
# 삼스파가 모였을 때 정말 좋았어요. 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 6
# 기억에 남는 액션이 없어요.. 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 8
# 전반적으로 너무 재밌게 봤는데 이제는 마블 스토리가 점점 복잡해져요 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 8
# 주인공 개 극암덩이샛기임 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 10
# 기존의 스파이더맨은 이번편을 위하여 만들어진 것이라 해도 과언이 아닐 정도로 좋았습니다.스파이더맨 전 시리즈 보시고 노웨이홈 보는거 추천드려요 ㅎㅎㅎ 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 8
# 아주 길었지만 시간 가는줄 모르고 재밌게 봤어요 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 10
# ㅠ 지렸다 역대급 스파이더맨.. 신고
# 스파이더맨: 노 웨이 홈
# 별점 - 총 10점 중
# 10
# 존잼 신고

# %%
# 영화 이름
print(b[0].text.split("\n")[0])

# 영화 평점 별점
print(b[0].text.split("\n")[2])

# 영화 평점 내용
print(b[0].text.split("\n")[3][:-3])
# Out:
# 스파이더맨: 노 웨이 홈
# 10
# 눈은 즐거웠습니다
